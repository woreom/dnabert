# %% [markdown]
# # Multi Layer Perceptron (MNIST) Pytorch

# %%
import sys
# !{sys.executable} -m pip install xlrd
# Out:
# Requirement already satisfied: xlrd in /home/woreom/anaconda3/envs/dnabert/lib/python3.6/site-packages (1.2.0)
# Collecting xlrd
#   Using cached xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
# Installing collected packages: xlrd
#   Attempting uninstall: xlrd
#     Found existing installation: xlrd 1.2.0
#     Uninstalling xlrd-1.2.0:
#       Successfully uninstalled xlrd-1.2.0
# Successfully installed xlrd-2.0.1

# %%
import torch
import numpy as np
import pandas as pd
from torchvision import datasets
import torchvision.transforms as transforms
from torch.utils.data.sampler import SubsetRandomSampler

from transformers import (
    WEIGHTS_NAME,
    AdamW,
    AlbertConfig,
    AlbertForSequenceClassification,
    AlbertTokenizer,
    BertConfig,
    BertForSequenceClassification,
    BertForLongSequenceClassification,
    BertForLongSequenceClassificationCat,
    BertTokenizer,
    DNATokenizer,
    DistilBertConfig,
    DistilBertForSequenceClassification,
    DistilBertTokenizer,
    FlaubertConfig,
    FlaubertForSequenceClassification,
    FlaubertTokenizer,
    RobertaConfig,
    RobertaForSequenceClassification,
    RobertaTokenizer,
    XLMConfig,
    XLMForSequenceClassification,
    XLMRobertaConfig,
    XLMRobertaForSequenceClassification,
    XLMRobertaTokenizer,
    XLMTokenizer,
    XLNetConfig,
    XLNetForSequenceClassification,
    XLNetTokenizer,
    get_linear_schedule_with_warmup,
)

# %%
config_class, model_class, tokenizer_class=(BertConfig, BertForSequenceClassification, DNATokenizer)

# %%
 model = model_class.from_pretrained("/mnt/d/M3/Projects/BCB/DNABERT/examples/OUTPUT/pre/3mer/checkpoint-17000")

# %%
model(**{"input_ids": "ACATCAGGTTACCTCTACCAAGG" , "attention_mask":3})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-a40327b55ea6> in <module>
# ----> 1 model(**{"input_ids": "ACATCAGGTTACCTCTACCAAGG" , "attention_mask":3})
#
# ~/anaconda3/envs/dnabert/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# /mnt/d/M3/Projects/BCB/DNABERT/src/transformers/modeling_bert.py in forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, labels)
#    1185             position_ids=position_ids,
#    1186             head_mask=head_mask,
# -> 1187             inputs_embeds=inputs_embeds,
#    1188         )
#    1189
#
# ~/anaconda3/envs/dnabert/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# /mnt/d/M3/Projects/BCB/DNABERT/src/transformers/modeling_bert.py in forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask)
#     700             raise ValueError("You cannot specify both input_ids and inputs_embeds at the same time")
#     701         elif input_ids is not None:
# --> 702             input_shape = input_ids.size()
#     703         elif inputs_embeds is not None:
#     704             input_shape = inputs_embeds.size()[:-1]
#
# AttributeError: 'str' object has no attribute 'size'

# %%
model.eval()
# Out:
# BertForSequenceClassification(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(69, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (1): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (2): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (3): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (4): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (5): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (6): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (7): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (8): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (9): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (10): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (11): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (classifier): Linear(in_features=768, out_features=2, bias=True)
# )

# %%
# number of subprocesses to use for data loading
num_workers = 0
# how many samples per batch to load
batch_size = 32
# percentage of training set to use as validation
valid_size = 0.2
# convert data to torch.FloatTensor
transform = transforms.ToTensor()
# choose the training and testing datasets
train_data_path = "/mnt/d/M3/Projects/BCB/DNABERT/examples/sample_data/ft/prom-core/3/train.tsv"
test_data_path = "/mnt/d/M3/Projects/BCB/DNABERT/examples/sample_data/ft/prom-core/3/dev.tsv"
train_data = pd.read_csv(train_data_path,sep="\t", header=None)
test_data = pd.read_csv(test_data_path,sep="\t", header=None)
train_data
# Out:
#                                 0  1
# 0      ACATCA GGTTAC CTCTAC CAAGG  1
# 1      CTGATG CCAGCT AGTGGG CGAGG  0
# 2      CTGTTT CCCATC CTTCCG GGTGG  1
# 3      AATGTA TGCACA GGGAAC AGAGG  0
# 4      CCAGAC TCACCC GCTTGC CCAGG  1
# ...                           ... ..
# 16744  CAACGC CCTGCT GCGGCG GCTGG  1
# 16745  CTAAGA AATCCT CTATCT TCAGG  0
# 16746  TGATCC GCCAGC GCCATA TCAGG  0
# 16747  ATCCGA GGTGGT ACCTGA TATGG  0
# 16748  TCTCTC TGCGCT CTCCCT ACGGG  0
#
# [16749 rows x 2 columns]

# %%
# obtain training indices that will be used for validation
num_train = len(train_data)
indices = list(range(num_train))
np.random.shuffle(indices)
split = int(np.floor(valid_size * num_train))
train_index, valid_index = indices[split:], indices[:split]
# define samplers for obtaining training and validation batches
train_sampler = SubsetRandomSampler(train_index)
valid_sampler = SubsetRandomSampler(valid_index)
# prepare data loaders
train_loader = torch.utils.data.DataLoader(train_data, batch_size = batch_size, 
                                           sampler = train_sampler, num_workers = num_workers)
valid_loader = torch.utils.data.DataLoader(train_data, batch_size = batch_size,
                                          sampler = valid_sampler, num_workers = num_workers)
test_loader = torch.utils.data.DataLoader(test_data, batch_size = batch_size,
                                         num_workers = num_workers)

# %%
import torch.nn as nn
import torch.nn.functional as F
# define NN architecture
class Net(nn.Module):
    def __init__(self):
        super(Net,self).__init__()
        # number of hidden nodes in each layer (512)
        hidden_1 = 512
        hidden_2 = 512
        # linear layer (784 -> hidden_1)
        self.fc1 = nn.Linear(28*28, 512)
        # linear layer (n_hidden -> hidden_2)
        self.fc2 = nn.Linear(512,512)
        # linear layer (n_hidden -> 10)
        self.fc3 = nn.Linear(512,10)
        # dropout layer (p=0.2)
        # dropout prevents overfitting of data
        self.droput = nn.Dropout(0.2)
        
    def forward(self,x):
        # flatten image input
        x = x.view(-1,28*28)
        # add hidden layer, with relu activation function
        x = F.relu(self.fc1(x))
        # add dropout layer
        x = self.droput(x)
         # add hidden layer, with relu activation function
        x = F.relu(self.fc2(x))
        # add dropout layer
        x = self.droput(x)
        # add output layer
        x = self.fc3(x)
        return x
# initialize the NN
model = Net()
print(model)
# Out:
# Net(
#   (fc1): Linear(in_features=784, out_features=512, bias=True)
#   (fc2): Linear(in_features=512, out_features=512, bias=True)
#   (fc3): Linear(in_features=512, out_features=10, bias=True)
#   (droput): Dropout(p=0.2, inplace=False)
# )

# %% [markdown]
# # Labeled SGRNA maker

# %% [markdown]
# ## df1

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('examples/sample_data/ft/prom-core/3/train.tsv', sep='\t', header=None)
df
# Out:
#                                      0  1
# 0      ACA TCA GGT TAC CTC TAC CAA GG   1
# 1      CTG ATG CCA GCT AGT GGG CGA GG   0
# 2      CTG TTT CCC ATC CTT CCG GGT GG   1
# 3      AAT GTA TGC ACA GGG AAC AGA GG   0
# 4      CCA GAC TCA CCC GCT TGC CCA GG   1
# ...                                ... ..
# 16744  CAA CGC CCT GCT GCG GCG GCT GG   1
# 16745  CTA AGA AAT CCT CTA TCT TCA GG   0
# 16746  TGA TCC GCC AGC GCC ATA TCA GG   0
# 16747  ATC CGA GGT GGT ACC TGA TAT GG   0
# 16748  TCT CTC TGC GCT CTC CCT ACG GG   0
#
# [16749 rows x 2 columns]

# %%
def space(string, mer=3):
    string = string.replace(" ", "")
    new_string=''
    k=23//mer if 23%mer==0 else 23//mer +1
    for i in range(k):
        if type(string)!=type(''): print(string)
        else: new_string+=string[i*mer:(i+1)*mer]+' ' if i!=k-1 else string[i*mer:(i+1)*mer]
    return new_string

# %%
string = 'GAGAACGGAAAGGAGAAGGGCGG'
space(string)
# Out:
# 'GAG AAC GGA AAG GAG AAG GGC GG'

# %%
df[0]= df[0].apply(space)
df.to_csv('examples/sample_data/ft/prom-core/3/train.tsv', sep='\t',header=None,index=False)

# %%
import sys
# !{sys.executable} -m pip install openpyxl
# Out:
# Collecting xlrd==1.2.0
#   Downloading xlrd-1.2.0-py2.py3-none-any.whl (103 kB)
#      |████████████████████████████████| 103 kB 508 kB/s eta 0:00:01
# Installing collected packages: xlrd
#   Attempting uninstall: xlrd
#     Found existing installation: xlrd 2.0.1
#     Uninstalling xlrd-2.0.1:
#       Successfully uninstalled xlrd-2.0.1
# Successfully installed xlrd-1.2.0

# %%
df = pd.read_excel("/mnt/d/M3/Projects/BCB/Crispr/Dataset/unlabeled_sgrna.xlsx", engine='openpyxl')
df
# Out:
#                           SGRNA  Unnamed: 1  Unnamed: 2  Unnamed: 3  \
# 0       GAGTCGGGGTTTCGTCATGTTGG         NaN         NaN         NaN
# 1       CGCCGCCGCTTTCGGTGATGAGG         NaN         NaN         NaN
# 2       GGCAGCGTCGTGCACGGGTCGGG         NaN         NaN         NaN
# 3       TGGGCGGATCACTTGACGTCAGG         NaN         NaN         NaN
# 4       TTACCATAGTGTACGGGTGCAGG         NaN         NaN         NaN
# ...                         ...         ...         ...         ...
# 634846                      NaN         NaN         NaN         NaN
# 634847                      NaN         NaN         NaN         NaN
# 634848                      NaN         NaN         NaN         NaN
# 634849                      NaN         NaN         NaN         NaN
# 634850                      NaN         NaN         NaN         NaN
#
#         Unnamed: 4  Unnamed: 5
# 0              NaN         NaN
# 1              NaN         NaN
# 2              NaN         NaN
# 3              NaN         NaN
# 4              NaN         NaN
# ...            ...         ...
# 634846         NaN         NaN
# 634847         NaN         NaN
# 634848         NaN         NaN
# 634849         NaN         NaN
# 634850         NaN         NaN
#
# [634851 rows x 6 columns]

# %%
def fix_df1(df):
    df1=pd.DataFrame(df['SGRNA'].unique())
    # fix sgrna with length 21
    for i in range(371409):
        if len(df1[0][i])==21:
            df1[0][i]+="GG"
            
    #fix sgrna with lenght 20
    temp=df1[0].unique()
    temp=temp[0:-1] # last one is NaN
    missed = [ i for i in range(len(temp)) if len(temp[i])==20]
    x=temp[missed]
    for i in missed: # fix sequenc inplace with adding A
        temp[i]+="AGG"
        
    temp2 = np.append(temp, [[x+"CGG" for i in missed],[x+"TGG" for i in missed], [x+"GGG" for i in missed]]) # appending the rest
    
    #check improvements
    counter=0 
    for i in range(len(temp2)):
        if len(temp2[i])!=23:
            counter+=1
    print(counter)
    
    # find uniques
    df1=pd.DataFrame(temp2)
    df1=pd.DataFrame(df1[0].unique())
    
    #save
    df1.to_csv("/mnt/d/M3/Projects/BCB/Crispr/Dataset/unlabeled_sgrna0.csv", index = False, header = False)

# %% [markdown]
# ### Test

# %%
df1=pd.DataFrame(df['SGRNA'].unique())
df1[0]
# Out:
# 0         GAGTCGGGGTTTCGTCATGTTGG
# 1         CGCCGCCGCTTTCGGTGATGAGG
# 2         GGCAGCGTCGTGCACGGGTCGGG
# 3         TGGGCGGATCACTTGACGTCAGG
# 4         TTACCATAGTGTACGGGTGCAGG
#                    ...
# 371405    GTCGAGGAGTCAACTTCTTGTGG
# 371406    GCACCTGTTCGATGTACTTTTGG
# 371407    GCAGAATATTCGGACAAACACGG
# 371408    AGCAACAGAGCCTATCGGCATGG
# 371409                        NaN
# Name: 0, Length: 371410, dtype: object

# %%
df1[0][371409]
# Out:
# nan

# %%
counter=0
for i in range(371409):
    if len(df1[0][i])==21:
        df1[0][i]+="GG"
        counter+=1
counter
# Out:
# 59852

# %%
temp=df1[0].unique()
temp=temp[0:-1]
len(temp)
# Out:
# 334005

# %%
df1=pd.DataFrame(temp)
df1.to_csv("/mnt/d/M3/Projects/BCB/Crispr/Dataset/unlabeled_sgrna0.csv", index = False, header = False)

# %%
counter=0
for i in range(len(temp)):
    if len(temp[i])!=23:
        counter+=1
counter
# Out:
# 1040

# %%
missed = [ i for i in range(len(temp)) if len(temp[i])==20]

# %%
x=temp[missed]
x
# Out:
# array(['GGAATTGCGAATTATAAAAC', 'GGGAACTCCTCAAACACAGC',
#        'GGAGACACTGCTGTTCTTTT', ..., 'GGCAACTTTTTATGCAAGTT',
#        'GGTAGCTGGGACTTGCCCTT', 'GGACTTCCAGGACTGCCTTG'], dtype=object)

# %%
for i in missed:
    temp[i]+="AGG"

# %%
temp2 = np.append(temp, [[x+"CGG" for i in missed],[x+"TGG" for i in missed], [x+"GGG" for i in missed]])
len(temp2)
# Out:
# 3578805

# %%
temp2
# Out:
# array(['GAGTCGGGGTTTCGTCATGTTGG', 'CGCCGCCGCTTTCGGTGATGAGG',
#        'GGCAGCGTCGTGCACGGGTCGGG', ..., 'GGCAACTTTTTATGCAAGTTGGG',
#        'GGTAGCTGGGACTTGCCCTTGGG', 'GGACTTCCAGGACTGCCTTGGGG'], dtype=object)

# %%
counter=0
for i in range(len(temp2)):
    if len(temp2[i])!=23:
        counter+=1
counter
# Out:
# 0

# %%
df1=pd.DataFrame(temp2)
df1[0]
# Out:
# 0          GAGTCGGGGTTTCGTCATGTTGG
# 1          CGCCGCCGCTTTCGGTGATGAGG
# 2          GGCAGCGTCGTGCACGGGTCGGG
# 3          TGGGCGGATCACTTGACGTCAGG
# 4          TTACCATAGTGTACGGGTGCAGG
#                     ...
# 3578800    GGCAGAAATGTGCTCTTGCAGGG
# 3578801    GGGAAGATTTTGGACTATTTGGG
# 3578802    GGCAACTTTTTATGCAAGTTGGG
# 3578803    GGTAGCTGGGACTTGCCCTTGGG
# 3578804    GGACTTCCAGGACTGCCTTGGGG
# Name: 0, Length: 3578805, dtype: object

# %%
df1=pd.DataFrame(df1[0].unique())
df1[0]
# Out:
# 0         GAGTCGGGGTTTCGTCATGTTGG
# 1         CGCCGCCGCTTTCGGTGATGAGG
# 2         GGCAGCGTCGTGCACGGGTCGGG
# 3         TGGGCGGATCACTTGACGTCAGG
# 4         TTACCATAGTGTACGGGTGCAGG
#                    ...
# 337120    GGCAGAAATGTGCTCTTGCAGGG
# 337121    GGGAAGATTTTGGACTATTTGGG
# 337122    GGCAACTTTTTATGCAAGTTGGG
# 337123    GGTAGCTGGGACTTGCCCTTGGG
# 337124    GGACTTCCAGGACTGCCTTGGGG
# Name: 0, Length: 337125, dtype: object

# %%
df1.to_csv("/mnt/d/M3/Projects/BCB/Crispr/Dataset/unlabeled_sgrna0.csv", index = False, header = False)

# %% [markdown]
# # df2

# %%
col_list  = ["sequence", "cas"]
df = pd.read_csv("/mnt/d/M3/Projects/BCB/Crispr/Dataset/GenomeCRISPR_full05112017.csv/GenomeCRISPR_full05112017.csv", usecols=col_list)
df
# Out:
#                          sequence      cas
# 0         GCAGCATCCCAACCAGGTGGAGG  hSpCas9
# 1         GCGGGAGTGAGAGGACTGGGCGG  hSpCas9
# 2         ATGACTCTCATACTCCACGAAGG  hSpCas9
# 3         GAGTCATCGAGCAGCTGCCATGG  hSpCas9
# 4         AGTCACCCTAGCAAAACCAGTGG  hSpCas9
# ...                           ...      ...
# 38473695  CTGAAACATTTAACCAGTTGTGG  hSpCas9
# 38473696  GACCAATATACCCATAGCCTTGG  hSpCas9
# 38473697  GTTCTTCAACAGTCCACAACTGG  hSpCas9
# 38473698  TATTGGTCCCATACGATCTCAGG  hSpCas9
# 38473699                      NaN      NaN
#
# [38473700 rows x 2 columns]

# %%
def combination(prefix=[''], allowed=['A','C','T','G'],length=3):
    newprefix=[]
    if length == 0:
        return prefix
    for i in allowed:
        for j in prefix:
            newprefix.append(j+i)
    return combination(prefix=newprefix, allowed=allowed, length=length-1)

def add(missed_data, missing=1):
    allowed = combination(prefix=[''], allowed=['A','C','T','G'],length=missing)
    need = []
    for i in allowed:
        need.append([i+x for x in missed_data])
    return need

def fix_length(array, length=20):
    
    if length < 23:
        # find missing data
        missed_index = [ i for i in range(len(array)) if len(array[i])==length]
        missed_data = array[missed_index]

        # remove missing data
        result = np.delete(array, missed_index)

        # fix missing data
        need = add(missed_data, missing = 23 - length)

#         print(need)
        result = np.append(result, need)

        # check fix
        counter=0
        for i in range(len(result)):
            if len(result[i])==length:
                counter+=1
#         print(counter)

        return np.unique(result)
    
    else:
        counter=0
        for i in range(len(array)):
            if len(array[i]) > 23:
                array[i] = array[i][-23:]
                counter+=1
#         print(counter)
        
        return np.unique(array)
        

def fix_df2(df):
    df2=pd.DataFrame(df['sequence'].unique())
    NaN=[]
    counter=0
    for i in range(747171):
        try:
            if len(df2[0][i])!=23:
                counter+=1
        except:
            NaN.append(i)
            
    df2=df2.drop(NaN)
    df2.index = range(len(df2))
    
    temp=df2[0].unique()
#     print(len(temp))
    temp = fix_length(temp,length=20)
    # print(len(temp))
    temp = fix_length(temp,length=21)
    # print(len(temp))
    temp = fix_length(temp,length=22)
#     print(len(temp))
    temp = fix_length(temp,length=24)
#     print(len(temp))
    df2=pd.DataFrame(temp)
    df2.columns= ["sgRNA"]
    return df2

# %%
df1=pd.DataFrame(pd.unique(df[['sequence', "cas"]].values.ravel('K')))
df1
# Out:
#                               0
# 0       GCAGCATCCCAACCAGGTGGAGG
# 1       GCGGGAGTGAGAGGACTGGGCGG
# 2       ATGACTCTCATACTCCACGAAGG
# 3       GAGTCATCGAGCAGCTGCCATGG
# 4       AGTCACCCTAGCAAAACCAGTGG
# ...                         ...
# 747169  GCCAAGCCAGAGAAGACCCGTGG
# 747170  GCTCCTGAGCGAGATGGCGGCGG
# 747171                  hSpCas9
# 747172               dCas9-VP64
# 747173               dCas9-KRAB
#
# [747174 rows x 1 columns]

# %%
df2=pd.DataFrame(df['sequence'].unique())
df2
# Out:
#                               0
# 0       GCAGCATCCCAACCAGGTGGAGG
# 1       GCGGGAGTGAGAGGACTGGGCGG
# 2       ATGACTCTCATACTCCACGAAGG
# 3       GAGTCATCGAGCAGCTGCCATGG
# 4       AGTCACCCTAGCAAAACCAGTGG
# ...                         ...
# 747166  GCAGCCGCCCGGCCTCACCGCGG
# 747167  TGTGAAAGATGCCTCCGCCGCGG
# 747168  GCATCTTTCACAGAATCCGGCGG
# 747169  GCCAAGCCAGAGAAGACCCGTGG
# 747170  GCTCCTGAGCGAGATGGCGGCGG
#
# [747171 rows x 1 columns]

# %%
counter=0
for i in range(747171):
    try:
        if len(df2[0][i])!=23:
            counter+=1
    except:
        print(i, end=", ")
counter
# Out:
# 695153,
# 83998

# %%
df2[0][695153]
# Out:
# nan

# %%
df2=df2.drop([695153])
df2.index = range(len(df2))
df2
# Out:
#                               0
# 0       GCAGCATCCCAACCAGGTGGAGG
# 1       GCGGGAGTGAGAGGACTGGGCGG
# 2       ATGACTCTCATACTCCACGAAGG
# 3       GAGTCATCGAGCAGCTGCCATGG
# 4       AGTCACCCTAGCAAAACCAGTGG
# ...                         ...
# 747165  GCAGCCGCCCGGCCTCACCGCGG
# 747166  TGTGAAAGATGCCTCCGCCGCGG
# 747167  GCATCTTTCACAGAATCCGGCGG
# 747168  GCCAAGCCAGAGAAGACCCGTGG
# 747169  GCTCCTGAGCGAGATGGCGGCGG
#
# [747170 rows x 1 columns]

# %%
myfix=[]
counter=0
for i in range(747170):
    if len(df2[0][i])==25:
#         df2[0][i]+="GG"
        myfix.append(df2[0][i])
        counter+=1
# df2=df2.drop(myfix)
# df2.index = range(len(df2))
counter
# Out:
# 269

# %%
myfix
# Out:
# ['CGGCCGCTGCTGCCGCTCCTTGTGG',
#  'CCGCTGCTGCCGCTCCTTGTGGTGG',
#  'TGGTGGCCGCGTGCGTCCTGCCCGG',
#  'CCACGGCGGAGCGGAGAGCCCTCGG',
#  'CGGAGCGGAGAGCCCTCGGCATCGG',
#  'GAGCAAGCGGTGGAGACAGAGCCGG',
#  'GCTGGGGATGCTGCGCTATCGGTGG',
#  'AATATCACCTACAGGTCACCGTAGG',
#  'TGCCGAAGCCCAGGACCGTGTTTGG',
#  'CTTGCCCCGAGGCCCCGGACCTCGG',
#  'CTGCTGCTGTTGTTGGCGCCGCCGG',
#  'TAGAGCGAACACGAACCATCCAAGG',
#  'GAGCCCGGGCGCTGGAGGCTCCTGG',
#  'CTGCGGGCCCCGGCCGCTCGCCCGG',
#  'CGGCTTCGGGACCGTACGCAAAAGG',
#  'ACCACTGCACAGTGCGCGTGTCCGG',
#  'GAAGTGGCTGAGTACCTGACCCCGG',
#  'ACCTCAGAGCCCGTTTGGATACTGG',
#  'CCAAGAGTAAGTTATTTGACGTTGG',
#  'AAGAAGCTGAACGAGTATCGGCTGG',
#  'TTTGCCCCTTTTAGTAGTGCCTTGG',
#  'GAGCAGCTGCTAGCCTCGCCCAAGG',
#  'GCCTGGGCACGCTGGCGCTGTGCGG',
#  'AGGAAAGCGGCGCAGCTGCCCTGGG',
#  'GTTGCTCTCCGGCGGCCTCCCTCGG',
#  'TGTTCCGTCTTCCACCTGTTCGTGG',
#  'AGCAGGACACGCAGGGCCTGGACGG',
#  'GCTGGTGGCTCTGCTCGCTGCATGG',
#  'CCTGGGAACCGCCTCAAGATCTTGG',
#  'ATCCTGGACCGTGTCACCATCCAGG',
#  'CCATTTATTGAAACTCCTCGCCAGG',
#  'ACGTCCAACAACAGCACCATGCAGG',
#  'CTCTGTGTGCTGGCCATATCGCTGG',
#  'CTGGCCATATCGCTGGCCTCTATGG',
#  'GACAATAGCATATTTGTCGCAAAGG',
#  'CTTCTGATTATTGATTCAAACCTGG',
#  'GAGAAAGAGAGGCGAACATGCCTGG',
#  'GAAACTCTAAAAAAGAACCGAGTGG',
#  'ATCATACATGGAAGCGAATCAATGG',
#  'CTCTTCAAGTGCTTCCGAAGCCTGG',
#  'CTGCTCTTCCGAATTAATAGACTGG',
#  'AGATGGAGAAGAGGGTCATCCTGGG',
#  'CTGTTCAGGCCCCATATGATCGAGG',
#  'TCTGGGGGCAAATACGTAGACTCGG',
#  'ACATCTCTACACCGTTCCCATCCGG',
#  'CAAGTGTACGACGCGCACACCAAGG',
#  'AAGGCGGACGTACAGCTCTTCATGG',
#  'TACGCCGACCCCGAGAAGTTCGCGG',
#  'AAGCATCTTTTCTTAATCCAAACGG',
#  'TGTGACCACGTGCAATATACGCTGG',
#  'GTGCTGCGGCCCGCAGGGCCCGTGG',
#  'GAGACTCTGAGCTGCCGCCGCGCGG',
#  'CTGGGCTCCCGTGAGCGGTTGCTGG',
#  'GGCTCCCGTGAGCGGTTGCTGGTGG',
#  'AGGATGAACAGAATCTGCCGGATGG',
#  'AACAGAATCTGCCGGATGGTGCTGG',
#  'AAGCTCTCCCGCCACCTCATGAAGG',
#  'CGCTGCTGCCGGCGGCGCGTGCTGG',
#  'TTCCCCCGCCCGCTGACCCCGCTGG',
#  'AGAAGCAAATACGCCCTTTTCTTGG',
#  'ATAGTTTTTGTCTTCATCGAAAAGG',
#  'GAGCCAGCCATGGAGGCCGCAGGGG',
#  'GCCTCGCGGCTCGTCCTGCCCCGGG',
#  'CCCGTGGATGAGCGTGGCATTAGGG',
#  'TTGGGCTTCATTCTCGCCTTCCTGG',
#  'CTTCATTCTCGCCTTCCTGGGATGG',
#  'GGTGACTCTGCCAAACAGCTACTGG',
#  'TTTCCGTGCAAAAGTCCAGCTCGGG',
#  'GGGGCTGCTTGCGTGGATTTCCCGG',
#  'CTTGCGTGGATTTCCCGGGTGGTGG',
#  'GGGGCAGCACACCCGACCCTCAAGG',
#  'CCAGAGCTGACTTACCCATTTCAGG',
#  'GTCTTTCTGCCCTGCATGTACCTGG',
#  'GCCTCAATGAGGAGTCCAAACATGG',
#  'GAGGACTTTTATGACATCGGAGAGG',
#  'ACCGCGACTTCGAGCCCTCCCTAGG',
#  'CTCTGCCCGGCGAGTCGGGCTCTGG',
#  'AGCAGCGCTATGGGCTGTCGTGCGG',
#  'TGACCTGCTGCAGCTTCGCTGTCGG',
#  'GGTCGTTTCATCTGCCTGGTCGTGG',
#  'CTCTGCGTGGCCGTGGCCATCGTGG',
#  'CCTGGGCCTCCAGTCTTGTCCCTGG',
#  'AGCAGGAGCTGACAGTAGCCCTTGG',
#  'CCAGCTTCCTACCTGAGGATGCTGG',
#  'GTAGTTATTGTCCAACTACCTGTGG',
#  'GACCCAGGAACCAGCAGAGGCCCGG',
#  'CTTTCCAGCCACAACGAGCTGCTGG',
#  'CGCCTAAGAAGTCCCGGGCCGCCGG',
#  'CCCATCGAGATCCCGATGTGCAAGG',
#  'AGATCCCGATGTGCAAGGACATCGG',
#  'ATGGGCCACGAGAACCAGCGCGAGG',
#  'ACGTGTCACACTTCCCTGTCGTAGG',
#  'AACTGACTGGCTTGTGCTATGTTGG',
#  'TTGCTGCTGCTCCTAGCGCAGCTGG',
#  'GCGGCCGCCGCGTCCAAGGCCCCGG',
#  'GCGCTGCTGGGCGCACTGTCCGCGG',
#  'CTGCAGCGCTCTAGCGGCGCTGCGG',
#  'CTGCTGTGGCAGCTGCTGGCGGCGG',
#  'CTGGCGGCGGGCGGCGCGGCACTGG',
#  'CGGGCGGCGCGGCACTGGAGATCGG',
#  'CGTCCGCCTTCCCGCTGCCCGCCGG',
#  'CGCCCGCCGAAGACCGCTCCCTCGG',
#  'CAGCGCTGGTCGCCTGCGCCCGCGG',
#  'CGTGCAGACCTGCGAAGAAGTTCGG',
#  'CGGATGTGAAGGCTCGGAGCTGCGG',
#  'CCAGCCAGACAAAGCCGCCTGATGG',
#  'ACAAAGCCGCCTGATGGAGCGTTGG',
#  'CAGCGACTCGGCGCCTGACTGCTGG',
#  'TCGTGGTGCTGTGTGTGGCCTGCGG',
#  'AGCCTGACAGACCCTTCGAAGTTGG',
#  'CCGATGCTGTGGCCGTTACAATGGG',
#  'ACATGCTGGCTGACAGCATCTCAGG',
#  'GATTCATCCTGTTACTGGTATTCGG',
#  'TGAAAAATTCAATGACTTTCAGCGG',
#  'TGCTTATTGGTTCTCCGTTAGTTGG',
#  'GAGATGTCTATAAGTGTCCAGTTGG',
#  'AACATCACCCACGCCTATTCCCAGG',
#  'GATACAGTGTCTTACAACATGTTGG',
#  'AAACCAATGGCTACCAGAAGACGGG',
#  'TGTACAAGTGTCCAGTGATCCACGG',
#  'ATGCTCTGTGCGCTCGCCTTGATGG',
#  'CTTGGGAAGCGAGGCGCGAACCCGG',
#  'GTCGGGGGCTTCAACTTAGACGCGG',
#  'AATCTCAGGATTGAAGACGATATGG',
#  'GGCTCGGAGCCGCGACCCTTGGGGG',
#  'TGGAAAAGCTCACAGTGTACAGCGG',
#  'CTCACAGTGTACAGCGGCCCCAAGG',
#  'CCCGGCTGCGCCGAGGGGCGCCGGG',
#  'CTGCTGCTGGCGCTGGTGGTCGCGG',
#  'TATACAAGCAGGGCCAAATTGTGGG',
#  'CCCTGGTGGGGCTGCTCTCCCTCGG',
#  'GCCTGCGGGTCCGTCTGCGGCCCGG',
#  'CGGGTCCGTCTGCGGCCCGGTGAGG',
#  'AAGCCCACGGTCCATCACCTCTCGG',
#  'CCTGTTCTTTCTATTTCTAGGAAGG',
#  'GCGCGGCGCTGCGCCCGACGAGAGG',
#  'CAGGCATAGTGGTGCCCAATGACGG',
#  'TCTGCCTGCAAAACGACCGGCGAGG',
#  'TTGTCTTCTGCAGTTGCCCCAAAGG',
#  'GAACTGTGCGGGCAGACGTGGCAGG',
#  'CACCTGCACCTGGAGTCTACCCAGG',
#  'CCCCTGCTCTCAGCTCTGGTCGCGG',
#  'CTGGAGCACAAAAGAGTCTCCGCGG',
#  'GAGCACAAAAGAGTCTCCGCGGTGG',
#  'CCGATTGCCAGGGTGCTGACCGTGG',
#  'ACTGCCCAGATGGGTATGACGAAGG',
#  'GCTCTCGTCGCCTGCCTAGCGCCGG',
#  'TCGCCTGCCTAGCGCCGGCCAGTGG',
#  'CAGATGAGTTCCGCTGTGACAACGG',
#  'CCAGCAGCCCCGAGTGTGCTTGTGG',
#  'CAGCCCCGAGTGTGCTTGTGGTCGG',
#  'CTGCTGCAGCTCCAGCATCTTGCGG',
#  'CGGCAGCGGCTGATCCGCTGCTCGG',
#  'CAGCGGCTGATCCGCTGCTCGGCGG',
#  'CATGTTTCCTTACTGTCGTTATTGG',
#  'ATAACCATCGTTATAAGTGGAATGG',
#  'CCATACACCTCGAAGCATTCCTGGG',
#  'CGCGGGACACGACGCCCCCCGCAGG',
#  'CCATGTACATCACAGCCCTGTTAGG',
#  'GACATTGTTATGGCCTCCTCCGTGG',
#  'CTTTTCTGGACCCCGAGCGGGGAGG',
#  'AAGACCCAATGTTGAAGTTCTCAGG',
#  'TTACTTGTCAAGTTTTTGCAGAAGG',
#  'ACTTTGAATATGATAAAAGCCTGGG',
#  'TTGCTCGAGCCAAGCACCGAGAAGG',
#  'ATGGGCTGCCAAAGGGACCGTGCGG',
#  'GCGAGGTTCCCGAAGGCCGACCTGG',
#  'CTGCTGCTGCTGCCGGGCATGTGGG',
#  'CGGCTGGATGACCTCTTCATCCTGG',
#  'GATGGCAAGCTCTTCATCGGCACGG',
#  'CCCGCCGAGGGTTTCAATCACCTGG',
#  'CCCAGGGGCCCTGGTGGTATGCGGG',
#  'TGGTATGCGGGAGCGTGCACCAGGG',
#  'CCGGGGCGCGGACGAGCCCGTGTGG',
#  'GGGCGCGGACGAGCCCGTGTGGCGG',
#  'GGGGCGGCGCGGGCCGGCGCCCTGG',
#  'CCTTCATGGAGAAGCCGCCAGCCGG',
#  'TGTAGGTAAATCGAGTATTGTGTGG',
#  'GGACTTCCTCTTTCCTCACCTGCGG',
#  'AGAAAATTCAAGTTGGTGTTCTTGG',
#  'ATTGCTATTCAACACCAGGTGCTGG',
#  'TCTTCTGATCTTGCGGATGAAAAGG',
#  'GCTGCCGGGGCGCTGGGCGTCGCGG',
#  'GGCCGATGCTGCTTCTACACGGCGG',
#  'CTGGTGACCAGCGTCACGCTGCTGG',
#  'CGCTGGCACTTGTGCGTGCTGCTGG',
#  'TGCTGCTGGCCCTGGGCACACGCGG',
#  'CTCTGGCTCTGGCTGTGCGCGCTGG',
#  'CGCGCGTGGATCCTGCTCACCTTGG',
#  'ATCCTGCTCACCTTGGGCTTGGTGG',
#  'CGCTTCAGCCCAGATGTAGCCCTGG',
#  'GATCACATATTTTCATTCGACCTGG',
#  'CCGGGGCTGCCGCCGTGATCCCGGG',
#  'GCTGCCGCCGTGATCCCGGGCCTGG',
#  'CCTTGCTGGTGGATGAGGAGCGTGG',
#  'GCATTCCGGACAATTTGCGTGTTGG',
#  'GGCTTCCCTACTGACCGGGGCCTGG',
#  'CCTGGACGCCCTCTACTCTCTGCGG',
#  'CTGCTGCTGCCGACGACGACCGCGG',
#  'GTGATGGAAATACTCTCTACGTGGG',
#  'CACTTAGCTTCTTCCACCAGAAGGG',
#  'TAGTACGGCGGTTCTCCCAGACCGG',
#  'GACTTCCTGACACTGACGCTGACGG',
#  'CCCTTCCCGCTACTGCTGCTGGCGG',
#  'CTGCTGGCGGTGCTGAGCGGCCCGG',
#  'CGGTGCTGAGCGGCCCGGTATCCGG',
#  'GAGTTCAGAGCGAAGAATGCTGTGG',
#  'TACTTCCCCATTATCCTGGTTTCGG',
#  'ACCTTGAACCGGACCTTGCTAGTGG',
#  'CGCGCCCGCGTCCCTGGCCCGCCGG',
#  'GGGGAGGAGGACGACGACTATCTGG',
#  'TTGTTCTTCATCATGCTCTCGCTGG',
#  'CCCCGGCCCTGGGCTCAGCCTCGGG',
#  'GGCGGGGCGTGTCGGCCCGGGGCGG',
#  'AAGCCCTGACCCAGAGTCCCGCCGG',
#  'CTGCGGGCATTGCAGATCGCGCTGG',
#  'CGGGCATTGCAGATCGCGCTGGTGG',
#  'AAGAAAAAGCCATCGACGTCACAGG',
#  'ATTAAAGACCAGGGAGCCCAAATGG',
#  'GAGAGAGGGGGAGAGGCCCGCTCGG',
#  'CCAACGGAGTGATCCCGCCGCCCGG',
#  'CCCAGCCGCAGCTACAGCGAGCGGG',
#  'CCCCCTCTAAGTCCAGACGTGGAGG',
#  'GATGAAGCTGTCCTGGACAGAGGGG',
#  'AGTCCATGTGCCGAAGAGTTACAGG',
#  'ACCAGCCACAGCAGGAACTGACTGG',
#  'AGATGGATACTCTGCAGCATGACGG',
#  'AAGCTCCGCAGCCTGCTGGCCGAGG',
#  'TCAATCCCGACGATAGAGAGCTCGG',
#  'ATGGAGAAGATTGTCAGGAAAACGG',
#  'TTGCTGCTGCTCCTGCAGGTGGCGG',
#  'GTGGCGGGGCCCGTGGGCGCCCTGG',
#  'GCGGGGCCCGTGGGCGCCCTGGCGG',
#  'AGAACATGACCACTGCCCCAAACGG',
#  'AACTTTGGCTTGCCACATGGCTCGG',
#  'TTGAAGATGAGGATATCCAAGCTGG',
#  'CTTCTCTGTCTTGTGACCGCAATGG',
#  'ATTACCAGCCGCCAACTTCACAAGG',
#  'GCATAAAAAGCAATATGTTCACAGG',
#  'TGCTCATGGCCGGTCCTGTGTTTGG',
#  'AACAGCTGCAGCTGCTGGAGCTCGG',
#  'AACATGAGCTCGAGCCCCTACAAGG',
#  'GAACCAGAATCCAGTTCTCCGACGG',
#  'ACGAGGCGTCTTGTTGCCGCTGGGG',
#  'AGGACCTGGAGAAGATCGGCATGGG',
#  'CCGTGGGAGGGAACCGACGAGCCGG',
#  'CCCAGGCTGGTCTTGAACTGCTAGG',
#  'ACTGGTAAGACCATCACTCTCGAAG',
#  'ACTGGTAAGACCATCACTCTCGAGG',
#  'CACTTGGTCCTGCGCTTGAGGGGGG',
#  'ATCCACCTGCTCACTGTTCAGCTGG',
#  'TTCCACTGGCAAGCCACTATTATGG',
#  'CACAGTGTTCAGCAGGTCCTGTTGG',
#  'TTCCATTGGCAAGCTACAATAATGG',
#  'TCTTGATATTCTACGATCACAGTGG',
#  'CGAATCAAGCGGGAGTTCAAGGAGG',
#  'TTCAAGGAGGTGCTGAAGAGCGAGG',
#  'ATGAGAATTTTACAGAATTAAGAGG',
#  'TCTTGGGGGGATGGTTCCATCATGG',
#  'GCGGAGAGTCCGACTGAGGAGGCGG',
#  'AGTCCGACTGAGGAGGCGGCAACGG',
#  'TCTACAGCCTCCGCTTCTCTCCTGG',
#  'CTCCTGCTGTCCGGCTGGTCCCGGG',
#  'GATCTTGGCAGTTCAGTTTCGATGG',
#  'GCCGCGGCGGCACAGAGACCGTGGG',
#  'GGCAAGTTCGAGTTCTCCCGCAAGG',
#  'GCCCCTATGGGGGGCGCCCCTCCGG',
#  'AGGCCGCGGACGCTCCCCCGGGCGG',
#  'TGGAGCAGCTGGATCAAGTCCACGG']

# %%
temp=df2[0].unique()
len(temp)
# Out:
# 747170

# %%
a="CGGCCGCTGCTGCCGCTCCTTGTGG"
len(a)
len(a[-23:])
# Out:
# 23

# %%
myfix=[]
counter=0
for i in range(len(df2)):
    if len(df2[0][i])>23:
#         df2[0][i]+="GG"
        myfix.append(df2[0][i])
        counter+=1

counter
# Out:
# 470

# %%
myfix
# Out:
# ['ATCAGCCAGAGCCCACACGGGG',
#  'AGCGGAGAGCCCTCGGCATCGG',
#  'CTGGCTGTTCCCCGGGCTGTGG',
#  'TTCCCCGGGCTGTGGCTGTTGG',
#  'GCCAAGGTGGAGCAAGCGGTGG',
#  'AAGAATGATGACCCTTCAAAGG',
#  'TTTCTGGTGATCCAGCCCCTGG',
#  'CCCCTGGTGATCTGGATGCCGG',
#  'ATAGGTGATAGTTGGGAATGG',
#  'GGTCTGTGATGTCACATCTAGG',
#  'GACAGACATGTCTTCCCATGG',
#  'TGATTGTCCAGGCTCGGCTTGG',
#  'AATAACCAAATGCAGCGGAAGG',
#  'CCACATCGTGCGGCAGCTGCGG',
#  'ATTAATACTGTGAAGGGAAAGG',
#  'GGGAAGAATTGAAAGTGAAGG',
#  'TGCTTCGAGATGTGTGGTTTGG',
#  'TGAAAAAGCACTTTCAGAAGG',
#  'TGATTCACCCCCAGGGGAGG',
#  'TCCAACAACAGCACCATGCAGG',
#  'CTGGCCTCTATGGTGACCGAGG',
#  'ACCTCTGACAGCACGTTCCTGG',
#  'GATGAATTATTACAGACAAGGG',
#  'GGGCTCCGCAGGGGGCACCCGG',
#  'GGCTGTATTGAAGAGCAGGGGG',
#  'CGATCCATCAAGACCACCCGGG',
#  'GCGGCTCCTGCGGCGGTGCCGG',
#  'GGCTGCTACGGGGCCATCCAGG',
#  'CAGTTGGAGCAGTTTATTTTGG',
#  'ACGGGCCCGCTCAGACCAATGG',
#  'AAGCTGGAGCAGCTGCTCCTGG',
#  'TACACCGAGTGCAGCCACTCGG',
#  'GAGCGGCGGCTGCGCGCGCTGG',
#  'GAGCAGCTGGCGCGGGGCGAGG',
#  'GCGGCTGCCCGGGGCTCGACGG',
#  'CTCAGCGTCACCTGGGTGGAGG',
#  'GCGAGTGTCCACTGTGCACGGG',
#  'TGCAAAAGTCCAGCTCGGGGGG',
#  'GCCCCCACTTCCAGCCCCCGG',
#  'GCTTTGACCCTGACTATGTTGG',
#  'TTGGCCAGACTTGCATCCGCGG',
#  'GTCATGTGCAAGAGCCTACTGG',
#  'AAGATGAGGCTTCTGGGATAGG',
#  'CATGTGAAGCTCACCGAGACGG',
#  'GTGAATCTGGATTGTTCTCGGG',
#  'AGTATTGCCGCGGTGGAAATGG',
#  'GTTGGGTCCGCCCGCAGCGAGG',
#  'AATACAGTGCATTTCGAGTAGG',
#  'ACACCCCACATCGACAATTTGG',
#  'ACCCGCTGGAAACACCCCTCGG',
#  'CACACTCCTCGCCCAGCCCGGG',
#  'GCGCCTGACTGCTGGGACCAGG',
#  'GTGGTGCTGAAGCTCTTTCTGG',
#  'TTCTCTCGGCACTGGTGACTGG',
#  'GAGATCCTAAGAAGCCGAGAGG',
#  'TCTGGTACTAAAGCATTCATGG',
#  'CACCATGGAGAGGAGGAGGTGG',
#  'AAACACTGGCCGTTCCGGGTGG',
#  'GCGGCGGGCGCGCTGCTGCTGG',
#  'AACATGAGGTGGCTGTGCTGGG',
#  'TGCAGCAGCACGACATCAGTGG',
#  'ACCGGCCGCCCCTACAACGTGG',
#  'TGCTCACCGATATGAAAAAAGG',
#  'TGGAGAATGTATACAAGCAGGG',
#  'ATGACATAGAAAATCCCAGAGG',
#  'TCTGCGGCCCGGTGAGGAGCGG',
#  'CCCCTCAGCAGCAAGGGTTCGG',
#  'GTGCATGTCCGCCAGACTGAGG',
#  'AGGTCCCGCCTCGTTCCTCTGG',
#  'GGTTTGAGGACTGTCCCGATGG',
#  'CCCGCTACCACTGCAAGAACGG',
#  'ACAAGAGCTTCATCTGCGATGG',
#  'CTCTCAGCTCTGGTCGCGGCGG',
#  'CAGTGCTCTTAGAAGTGCAGGG',
#  'CGCTCTGGCCCATCCAGACCGG',
#  'GGCACCTTACAGAGGCCCCTGG',
#  'GGATTATTGCCGATTGCCAGGG',
#  'TTGCTTTATGCAAACAGACGGG',
#  'AGAATGCTACGATTGTAGTTGG',
#  'TGTTGTTGAAGCTATTTCTGGG',
#  'AAGAAATGCTCTTTTGCTTGG',
#  'GGAATCTGGAAGCACTTACAGG',
#  'AAAAGCAATCGGGAACTTCTGG',
#  'TGTGCGGGGACAAGGTGTCCGG',
#  'CAGGACCCGCCCATCAGCCCGG',
#  'ATGGTGAGCATCTTCTGCTCGG',
#  'ATCTCGGGAAAGATCACGTCGG',
#  'GCTAAGGGCAGGAGCTACCTGG',
#  'GCCAAGTGGCCATCGTCACCGG',
#  'GCGTCCAACCCCGAACGGGGGG',
#  'CAGAAATTGGATGATATCAAGG',
#  'CCCCCCTTCCGCACCTTCTCGG',
#  'GGACGGGGGCCGTCTATGTGGG',
#  'AAGTGCACGCCGCCCATCGAGG',
#  'CCCCTGCTCGCCTATCTGCTGG',
#  'CACCGCCGCCGCCGCCGCCGGG',
#  'ACTCACCTGGGTACTGGTATGG',
#  'GAACGTTCTCCTGGTGCAATGG',
#  'GAGAAGCCGCCAGCCGGCAAGG',
#  'CTGTACAGCATAACCCGCCAGG',
#  'TGGTGATAGTGGACTGGATGGG',
#  'GAGGACCAGGTGTACAACTAGG',
#  'AGTATTGTGTGGCGGTTTGTGG',
#  'ATGACTCAAATCATACAATAGG',
#  'TCAAAAACCATGTACTTGGAGG',
#  'AGGGCGGTATGCGACACACGGG',
#  'CGTCGAGCGGCGGGGAGCTAGG',
#  'GCTGCCATCCGGAAGAAACTGG',
#  'GGCTTGGTGGCCTGCGTGTCGG',
#  'GCGGTGTCCACCACACCTGCGG',
#  'CGCTGCTGCTGTTCTTCGTAGG',
#  'CTCCTGTGGGGTTACTTACTGG',
#  'GGCCATTTGCTGGCTGCTAGGG',
#  'AGGGAGGAGTGTGTTCGAAAGG',
#  'TTGCCCACCACCTCGTCCCTGG',
#  'AACCACTATCCCGTGTTTGTGG',
#  'GCAATATCCGGTTTTTAGAGG',
#  'CGTCCCTGGCCCGCCGGCTCGG',
#  'CTGCGGGACAACTACACCCTGG',
#  'TTCAAGCTACGAAAATAAACGG',
#  'AGAAGGGAAAGGAGTATGATGG',
#  'ATGGAGGAGAATCTGGAGCAGG',
#  'ACATCCCCGAGTCCCAGATGG',
#  'AAGCAGTTGTGGATAGAGGTGG',
#  'CAGCATGGATCTTATCAGCAGG',
#  'TTTTTGTTATTGGGTCCAGCGG',
#  'AAGAAGCTGTTGTGGATCTTGG',
#  'CTCCTAGAAATATTCCTTCAGG',
#  'AAGGAAGACCGTGTGGACGAGG',
#  'CACAGAAAAATGGCTCCGCTGG',
#  'ACCCCAGCCACAACGACACTGG',
#  'CGGTCCGTGGCGCCAGCTTTGG',
#  'AGCAGCACCCCTGGCCCAGTGG',
#  'GACAGGATTAACGAATATGTGG',
#  'ACGGAGTTTATCATCACCGCGG',
#  'TGGCCTCAACAATCGCATCCGG',
#  'TATTTGTCTCGATATTCTGAGG',
#  'AATGGAGATCAACCATTCTAGG',
#  'AATGGAGGTCAACTATATTGGG',
#  'GATTACGACTATCATTTTTGGG',
#  'ATCGGCCACGGCGCCTTCGCGG',
#  'TGAATTTCTCCGCATCAAATGG',
#  'CTGTTTTCTCTGAGTTCTGTGG',
#  'ACATGGTATTGCAGTAGACTGG',
#  'ATCTTATCGGAGATGAAAAAGG',
#  'AATCGGCAGTTGTCCACACTGG',
#  'TATAAGCTCATCCTCAAAAAGG',
#  'AATATGGTGGCCCTCCACCTGG',
#  'AACATGCACCAGGCGTGCATGG',
#  'GAATCCCCAATCACGTCCCCGG',
#  'AGATGAGCAACCGAGCGACAGG',
#  'ACCCACTGGTAGCCGTAACAGG',
#  'TGCTCATCCGTGGTAGCATTGG',
#  'CGGATGTCTCCAAGGTAAAGGG',
#  'CAAGGGGCCGTTTAGCCGGTGG',
#  'GTGGATTATTACATCGACCCGG',
#  'CAATCCGGGTGTCGGGAGTTGG',
#  'GCTGTACGCATATCCAATGAGG',
#  'TGGAGGCGTCGGAGAGCACGGG',
#  'GACTGGTACGCGGCCGTGCAGG',
#  'AATGTCCAGATGCTCCCGCTGG',
#  'ACGTGCTGGTCCTGATGAAAGG',
#  'ACGTGCCAGTAGATCATGATGG',
#  'CCACCGTATTTCCAGATGATGG',
#  'GCAGCCTTTTCATATCCAAAGG',
#  'AACGTTGTCTATTGCTGACAGG',
#  'GCAGCAGACTCTACGGAACAGG',
#  'TTCTTTCAAGTCCCACCAGGGG',
#  'GCCCATCGACAGAGTGCCAGGG',
#  'GTGAAGACGGCATCCGGCTGGG',
#  'AGGATCCCCTAAAGACCCCTGG',
#  'CCTTTGTCAGTTGTAGGACAGG',
#  'CATACACCTGTTACCAGCTTGG',
#  'TTATGATGACTTGTACCATTGG',
#  'AATCGCAGATGTCCCCGAGTGG',
#  'TCACATTCACACCGAAGTCCGG',
#  'ATGCACTTGGGTGCGCCCGTGG',
#  'CCTTACCGTGGTGTAGCACAGG',
#  'GCTACATTTGTGGAGCTCCTGG',
#  'AAAGTCTGAAGCACTAAGAAGG',
#  'GGGGGTTGTTTTACATCCATGG',
#  'TTTCTATCCAAATCACTCATGG',
#  'ACATGTTGTCTGGAAAGCATGG',
#  'AACTTGTACATTTACGGTAAGG',
#  'TTGGCAAGTACAATCGTACTGG',
#  'GACTTCCTGAATAGATGGACGG',
#  'CCGCAATGCAGATTCGGGTGGG',
#  'GCAACAGCGGTCACTCAACAGG',
#  'TGAAGTCCCTGGATGCATATGG',
#  'AGTTGTTGACAAACCACTGCGG',
#  'GGACAGGCCAGATCTGCCCCGG',
#  'CGAAGGGGTTTGTAAATCCAGG',
#  'CCTGAGAGGTTTAAGGAGAGGG',
#  'CACCAAAGTGACCAGGTAGAGG',
#  'TTTTGGGACGATACCCGTGAGG',
#  'AAATACTGTGGCCCCTCCATGG',
#  'GTCTTGCAGATTGTTACCATGG',
#  'CCGGGCCAGATAATTGCACAGG',
#  'TGGATCTATGTGTCACATCTGG',
#  'TTCAGTATTCTCCGAGTGCTGG',
#  'CCGTAATCACTGTAGAAAATGG',
#  'GTATGTCTCTTAGGGAATCTGG',
#  'AATAATGTTGCAGCCCAGTGGG',
#  'ATCCAGTCAGCTTGCAAAAAGG',
#  'GACTGTCCAATCACTATAAGGG',
#  'ATCTGCAAGGAATACGTAGAGG',
#  'CACGAACACCACCACGGCGCGG',
#  'CCCGGAACAGCGCGCCGAACGG',
#  'ACCACCCCGATGATCAGAGAGG',
#  'CTGGAACAAACCATAGCATTGG',
#  'ACTACATTGGACCACACATTGG',
#  'ATGACTTCCCAGAATCTACAGG',
#  'AGTCCAGAGGAGTTGCCTGAGG',
#  'ACGCCTTCTACTCAGGCCCAGG',
#  'TTCAATTGCACCCCGCCAGAGG',
#  'CCGGCCTTTTGTCAGGGTCTGG',
#  'GGCAAAATCATCACTACGAAGG',
#  'TTCGGCATCGGGCGACAGCAGG',
#  'GAACTTGATCCCGGTCCGCCGG',
#  'TTCGGGACTTTCCACATCCAGG',
#  'TCGCTGAGCCGCCATACGAAGG',
#  'ATACCTTGGCAGTGACCGGGGG',
#  'GGTGACCTCGCTATCGTCGGGG',
#  'GCAGCGAAACTCACTGGCAGGG',
#  'CCTTCACGCTCGATCTCAAAGG',
#  'ACATAGGGTCAGGAAGTGCCGG',
#  'AGGGACAGCTCTGGACATAGGG',
#  'CTTCATCATCGGCTCGCTCTGG',
#  'ATTGACTATAACTCCTGGGAGG',
#  'ATCTTCACGCCCCGGAACTTGG',
#  'GTGGACAAGGCTAATCCGAAGG',
#  'AAGGAAGAAACCCATACGAGGG',
#  'ACAGGTAGCACATCGGAAAAGG',
#  'GTCGCACGCGGGACGAGGTGGG',
#  'CGTGCGACTTCTTCGGGGACGG',
#  'GCTGGAGGACCTCAGACGACGG',
#  'CTGACGCGCGCCTTCCAGTGGG',
#  'GCGATCTCGAGGCGCGTGCAGG',
#  'TACGCTATCGAAGAGCTCCGGG',
#  'GGCGTATCGGACAGCTCGGCGG',
#  'GCCGCACATCTTGTCAACCAGG',
#  'ACCACCAATCCGGTCGTAGTGG',
#  'GGGGGCAAACATAATGACCTGG',
#  'ATCCGCCTACCCCGCTCCAGGG',
#  'CGAGCTGTGCGTTTCTCCATGG',
#  'CGACGAAGAACCAGCCTAAAGG',
#  'CCTTACTTGGGCCGAGTAGGGG',
#  'ATCCACGAAGCGAGATGGCAGG',
#  'GGAGCAACTTGACGGAAGTTGG',
#  'TCCACAACAGAAGGATCGAAGG',
#  'TAGAACTTACCGAAAATGCTGG',
#  'TAGCTCGCATTGTGCCAAGTGG',
#  'CTCTTCGAGTATTAGCCCTTGG',
#  'GTGCGATCGATTCAGCCCGAGG',
#  'GTCCCGGGCAAAGACGAACTGG',
#  'TAAAGTTGAAATTCGGGTAAGG',
#  'CAATTCCAACTTGCAGCTCAGG',
#  'TTATCAGGTAATGTACCGTTGG',
#  'TGTGCCGGCAAATTGTCAATGG',
#  'CTTACTTGTGTGGTAATGCAGG',
#  'AACGACTTATGTAGCGCTCCGG',
#  'GATACAGCCTTCGAATCGGCGG',
#  'GTGGGTAGCATTAGAAAACTGG',
#  'CCTTTTGTCCGTGTCCAAGAGG',
#  'TCTACTCACCAGACGATCCTGG',
#  'GCCACTCTGCAAAAACACCGGG',
#  'GAGCCGTGAAGAACCAGATAGG',
#  'CCGCGCCAAGCTTCTGCGAGGG',
#  'CCACCCGTCGACGTCCCCTGGG',
#  'GCTGACCCTGTCGGACCGCTGG',
#  'CGCTGGATCGCGCCAGAGCTGG',
#  'TCGCAACAATTTCGTGCACAGG',
#  'GCAATTACGAAGAGAGCCGAGG',
#  'GTGGACGGCAACCGAATGCTGG',
#  'ACCCGGTACCACATGAAGATGG',
#  'CATGGGCGCGTTCCATGGGAGG',
#  'GCCGTGGGAACGGTGCGATGGG',
#  'ATATTCCCCTGCGGGAGTAAGG',
#  'ACCTTAGATCCCCCGACAAAGG',
#  'GTTCTATGCCCGCTTGAAAGGG',
#  'TGAGGACATGCGGTACGTCTGG',
#  'CGAGTACTTCGTTCCAACATGG',
#  'AGACGACAAATCTATGCAGTGG',
#  'GTGTTCTGACCAGGGCATAAGG',
#  'TTGTTTCTGAAGCGAAAGTGGG',
#  'ATGAATCCCCAGAGGGATCAGG',
#  'TTGTTACTTGGCAAAGTACTGG',
#  'CTGCCATACCGTATGTCCCTGG',
#  'ATTGCACGATACGAAGAACAGG',
#  'GCTGTAGTCCGAAAAATACAGG',
#  'GTCTTGAGACTCATCCGGATGG',
#  'CGGTCATATAATACACAAGAGG',
#  'GTCATGCGTACCCTTAAGAAGG',
#  'TAGACCCCTGCAATGTCCATGG',
#  'CTTCAATGACGGTGAATCCAGG',
#  'GATCTCAATAAGACCGAGGAGG',
#  'TGGCTGCGAGTCTACCAACAGG',
#  'CGGATGTCGTGCCCGTAGATGG',
#  'ATGTACGTGGCGATCCGAGAGG',
#  'GATCCAGACGAAGCCGTAGAGG',
#  'CGAGATCCGCCGCGCCTACTGG',
#  'TGACAACGCGGCCTGCGGCTGG',
#  'GTGGACGGGCATACATCAGCGG',
#  'GTCCACGTTGACGGGACTCAGG',
#  'AGTCATCCAGTTGTACCGAGGG',
#  'TGCGATGAACGGCGGGTACGGG',
#  'TCGGCATGGTACTCCATGATGG',
#  'AGATTGAGCGTCTCGAGTAAGG',
#  'CACGAATCGTCCACGAAGCAGG',
#  'CGAATGGACATAGACGTGGTGG',
#  'CGGATCTTATACTTCACGTGGG',
#  'CTCGGCCGATGGATAAACTAGG',
#  'GTTGTAATAAAGTAGCTCCAGG',
#  'CTGAACACTGTCACCCGATTGG',
#  'CGCAATGACTGCCATAAGAAGG',
#  'AAAATTACTCCTCGGGGAAAGG',
#  'TTGCTCGGCTTAGAGAGACTGG',
#  'CTTGTATATACTTTGCCACTGG',
#  'GGTCAAATCACGGCAATCCTGG',
#  'GAATCTTAGATTATCAAACTGG',
#  'CCCAAATTATAGTCATGACTGG',
#  'AAGTGGACTGTTATATCCCTGG',
#  'ATTTTGATGCGCACGTGGCCGG',
#  'ACGTAGCGCAGGTCGGTCAGGG',
#  'GACCGTGGACGAGCACGTCTGG',
#  'TCCGGCTACTACCTGACGCTGG',
#  'AAGCTGATCGCCACGCTGAGGG',
#  'TTGATAGCTATCCTGACCTAGG',
#  'AAACCAGTGATTACCCGCCAGG',
#  'AGCGCCTCCAGAATTCCAAGGG',
#  'AATCGCCAATGCCAGATAGAGG',
#  'TGAGATTTGAGCCGTCCGATGG',
#  'GAAGGTGTTCATATCCAATGGG',
#  'GAAGACGTGTATACAATGCTGG',
#  'GATCCCCCAAAAGACAATAAGG',
#  'AAACACAACCAAGCCCGTAAGG',
#  'CACAAATTGTCGTCCTGACTGG',
#  'TCGTGGTGGCAAACAATACAGG',
#  'TGACAGCTATTCGAAGAGTGGG',
#  'TCTTAGCGTATGCAAAAGCTGG',
#  'CTATAATGCGACAGGAGATAGG',
#  'GGTATGCCTATTATTACAGTGG',
#  'GTGAACGGCGATAGGGACCCGG',
#  'AATACGTTCCTCAGCTAGCTGG',
#  'GCCACCTTTGTTTTGAGCGTGG',
#  'TACAAGTTGGATCGAATCAAGG',
#  'TCTTGTGTTCGCCCAGCGTTGG',
#  'GGTCATGCGCTGAATGAAAAGG',
#  'CTGTCGCAGTACTTATCACAGG',
#  'AATGAGTAGCACGCCTGGCTGG',
#  'ATTTCGGACCGTAGACAGTCGG',
#  'CTTGACGTTAGCTCGAGAAGGG',
#  'AATACGCGGCTAACAGAGTAGG',
#  'CCTTGTCGCTGCTAAATCCAGG',
#  'TTAGTTTCGATACTCCGATTGG',
#  'TTGATATTGTTACTGATGGTGG',
#  'GATGTGACTGATGAAGAGATGG',
#  'AATGCGTATGATTTTATCATGG',
#  'AAATTTAATACATTGGTAGGGG',
#  'AGGAGCTCAAATGAGTGGAGGG',
#  'AAAGGTCGGACTACAATCGTGG',
#  'TATCTAAGGCTATTGACAGAGG',
#  'TAGGCTCGAGCGGTTCCCAAGG',
#  'TAGTCTCTGTTAGCGGCTCAGG',
#  'CACAGTTGCAGTCACACGGTGG',
#  'TGGTAACCCTTGGAACACTTGG',
#  'GTACACAAGGGACCACGTAGGG',
#  'AGCCATGCGCTCGCCAACGTGG',
#  'TCTTTGACGCCAATAAGACAGG',
#  'GCGTGTCGACAGCATGGACAGG',
#  'TCCCGTTGCTCCATGGCGAAGG',
#  'CGAAGGCGAATGTTCAGTCTGG',
#  'CAATTAGCTCATTTGCCGCAGG',
#  'TCCTACACCAAGCCCGACGTGG',
#  'ATGTACGTCCACACGAACAGGG',
#  'CCCACGAAGAGGCACACGAGGG',
#  'TATTACAGGTCCGTGATACAGG',
#  'CCAGAAGGTGATCCTCGACAGG',
#  'TAGCCCCGGACAATCAACCTGG',
#  'ATCGTCAAGTCCCCACAGAAGG',
#  'ACAATCTCCCCGACCGTGGAGG',
#  'GTCACGCTTTTCCTATGCCTGG',
#  'GACGGTGCTATCTGGCACTTGG',
#  'GTAACACTTCAGGCACGGGGGG',
#  'AACCGGTAGGGCAGCCCACAGG',
#  'GCACGCTGTCCTCCGCTAAGGG',
#  'ATCTGACGGTCGGAATAGACGG',
#  'GATCGTCAGCGGGAACATCAGG',
#  'TGTCCCGGGATCGTCAATGGGG',
#  'CAGATGACCAGCGATGCGCAGG',
#  'CGTTGGTTGATGATCCAACTGG',
#  'CGCAAACTCACCGCACCCGTGG',
#  'ACGGCCATCCGGTTGAAGGTGG',
#  'AGTCATATGTCGACAATGGGGG',
#  'GGTGAAAGGCTACCGGCAAAGG',
#  'AGGTTAGCACCCAACCCGGTGG',
#  'GCAACTCACTCTCGGACTGTGG',
#  'GATTGGTATATCGAACAGCAGG',
#  'TATCGAGAGAATCCAGAATAGG',
#  'GAGTAGCATTACCTACAGCTGG',
#  'AGACATCCTCGAGTGTCAGAGG',
#  'CGACCCACAGGTAGATGCAGGG',
#  'GCCACGACAATGGTGCCGCAGG',
#  'ATACAGTATGAGCGGCTGCAGG',
#  'GGATGCCGGTAGCCATAGATGG',
#  'AATGCCTCCGGCGAGGACGAGG',
#  'GCATCCGAAGAATCCAGGTTGG',
#  'CGTCACTGCCACGAACACGCGG',
#  'TGCAACTTTCACGGATGCCAGG',
#  'GCACTTCGTCTTAGTAACATGG',
#  'TGCCATATGATTTATCGGAAGG',
#  'CCCGTGTGGCCCACAAGAAGGG',
#  'AAGCCCAGCATTGTCCACTGGG',
#  'ACTTGGAAGTAGTCCGGATGGG',
#  'ATTCTGAGCTGAGAATGCATGG',
#  'AAGTTCAGGAGAACTCGACCGG',
#  'GGCTGTTGTCGGTCCAGTGGGG',
#  'CGGGTGTCCTTTGACCGTCTGG',
#  'ACCCCCCAGGTCGCACTGGTGG',
#  'CTGCCTCTCGTCTGGATCGTGG',
#  'TCTTGCCGTAGGAAGGGCTCGG',
#  'CCGGAGGTAGCCCCGGCCATGG',
#  'TCCTCTTCATCCACCACCATGG',
#  'GAGGAGGTAGATGGGACCAAGG',
#  'GGTACCCCCCATGTACCTCTGG',
#  'TGTGCTTCCTGAGAACAGCAGG',
#  'TCACCATTCGTATCCCCCGAGG',
#  'ACGGTAGATCGGACCACACTGG',
#  'GACTCCGAGTATGTAGTAGAGG',
#  'CCGATGGCTCGCAAGTCGATGG',
#  'CGTAGCTGCGAGAAGCCGATGG',
#  'GTTAGACGTAGAGAGCCTAAGG',
#  'GATCAATGTCATTCGAGTCAGG',
#  'CAACGAATCCCATCACGGCTGG',
#  'TCCGGGACATAACCTGAGATGG',
#  'GCGGGCCACATACACCGACAGG',
#  'ATCGTCCGCAAGGACCCGCGGG',
#  'CAGACGGCTGCGGAACGACAGG',
#  'TACTACCGGGTCAGCAACATGG',
#  'CGCTACATGCACTCGCGTGTGG',
#  'GCTTTTAACACTTTAGCAGTGG',
#  'CTAGTAGGGTGGGCCCAATTGG',
#  'AGTGATCAATATGGATGGGAGG',
#  'ATTTGATGATGAAAGTCCGAGG',
#  'GCAAGCGTTTAAAGCAATCTGG',
#  'CCTCATTGTTCTGTAATGGTGG',
#  'TGGTATCATTGGTCGTAGCAGG',
#  'ATTAAACTTACAAGAGGCATGG',
#  'TAAACTGTGCTTCCGAGTAAGG',
#  'CTGAAGATACTCCTCATAGAGG',
#  'TAGTAGACGAGGGTGAACGGGG',
#  'GATGACATCGATAACCCGTAGG',
#  'AGGACCCCATAGTACTGACTGG',
#  'TCACTCACCCAGTAGGGTCAGG',
#  'CCAGGAAAATTATGCATAGAGG',
#  'ACAATTGATAAGGCGCCAAAGG',
#  'GGTTGCCTATCCCTCGTCCAGG',
#  'AGCATCTCCGCTCATGGCAAGG',
#  'TTGTAGCCGGCCGCCGCTACGG',
#  'GCCAAAGCACGGCGGATCCTGG',
#  'GAGAAGAATCGGATCAATAAGG',
#  'CGGGAGGACATCTCCGCCTGGG',
#  'GGACCTAGATGCTTGCGTGTGG',
#  'TCGCGGATCTTGCATGGACTGG',
#  'AGCTTCTCACACTCCGCTGTGG',
#  'GGGCATCTCTCGAGTCAGATGG',
#  'ACCAATGAGGCCATAACGACGG',
#  'TTTGCCTTAAGTCGAGCCTCGG',
#  'GTCTTTTGGCGATAGGTGAGGG',
#  'AGCGGATGTGAACCTGGCATGG',
#  'CGAGAGGATTTGCTACGGAGGG',
#  'GGGCATCAGTCATTCTCGCTGG',
#  'CCCGGAAATTCCTTTCAGGAGG',
#  'TTGCGCCAACACGCGGACCGGG',
#  'GGTGGTCAGCGCAAGCGCCTGG',
#  'ATGAAAGGGCTCGCTCAAGGGG',
#  'GCTCGAAGAGTTTGGCGCTGGG',
#  'TCTTGGATGAGCCTACAACTGG',
#  'GTCATTCAAGAGTTAGGTCTGG',
#  'ATTAGATGTCTTAGCTGCAAGG',
#  'ACAGTGGGATCATGAAACCTGG',
#  'AACTTAGGATGTCTAAGCAGGG',
#  'GGCCCCTCCCGCACGGAATAGG',
#  'TACCCCTTTTGCGCCAGCAGGG',
#  'TCAGGTAAATTCTGCCGCCGGG',
#  'CGTGTGGGAGCACGACATCAGG',
#  'GCCGAGTCCCTTTAGATAGGGG',
#  'AAAGATGTCTCCTTGTACGTGG',
#  'CCTTTAAAGCCACCGCGTGAGG',
#  'TTAGTGGACCTGACGTCAGTGG',
#  'ATTAGCAGTCATGCAGTCCAGG',
#  'AATCAGTCGGTCTGCCACATGG',
#  'GTCTCTCGCACAGTCAAGTTGG',
#  'GTTACCCTTTTGTCACGCTGGG',
#  'GGGCAACATGTACGTGCGGGGG',
#  'GGTGCCAGACGTCATCAGGAGG',
#  'GGCCGCCCCTAAGTAGATGGGG',
#  'GACTTTCTACCCAACGCTGTGG',
#  'GCCCCTAGTCCTTTATCAGAGG',
#  'TGAGGGATGGCTACCAGTAAGG',
#  'CTGTCGTGTTTAACAACCGGGG',
#  'GGTTTGCCCTCAGACCCACAGG',
#  'GATACCTCAGCGGGCGCCACGG',
#  'TTTTAGCTTCTTATAAGCCAGG',
#  'CATATAAGAAAGATAGCCAGGG',
#  'ATGAATGGTACAAAAGCGTTGG',
#  'TCTAGGTCACGCCTGCATAAGG',
#  'ATGCTGCTGGCACTACAGAGGG',
#  'TGTGGCCAACGACGACGCAGGG',
#  'AGCTACGAGATCATGAGCCAGG',
#  'CGTGCAAAAAGACGACGGCCGG',
#  'CACGGCCCTAGCTTCGCGAGGG',
#  'GACATAGTTTGATGAGAAATGG',
#  'TTGCAGGCGAAAGGGCGTGTGG',
#  'GCCCGCTTCATTCCCGCGTCGG',
#  'AAGCAGAACCTACGCCTGACGG',
#  'GGTACCTGCGTTCCCATGCAGG',
#  'TTATTTTGATACGATACACTGG',
#  'AAATTATAGTTGGGGAATAGGG',
#  'ATGGGAATGCAGGCAACATAGG',
#  'TGGTTGATTATCGAGGATATGG',
#  'ATAAAGGAAGGTAACGCATCGG',
#  'TGATTTTGTCAGTGCAGATGGG',
#  'GGCACAAAGCCCGGGAGCTGGG',
#  'ATGGACTGATCACAACCGGGGG',
#  'CCTGCCCCTATTGGGGAGCTGG',
#  'GGCGCGCACGTCATCCCAGCGG',
#  'TACGCGCTGGCCCACTCGCTGG',
#  'GCCTCGTGGAGCGCTACCACGG',
#  'ACGCGGGCTTCTACGAGATGGG',
#  'GGCGTTGGCGTCGTGCTGAGGG',
#  'TCGGCCTGTCCCAGGTACACGG',
#  'CAGGAGACGCGGTTGCCGCGGG',
#  'GAAGTCGGCACGCTCCGTCAGG',
#  'TCTGTGGGTTTCCCGGAACTGG',
#  'CATATGATTATTCTGGATATGG',
#  'TTACATAGGACTAGGATCACGG',
#  'AGTAAAGTGTATTTCGCATTGG',
#  'TCATGACTAGAACCAGTAAAGG',
#  'AGCACCGTGTAGGTGGGCTCGG',
#  'CCTCAGCGAGCGCGCCGACTGG',
#  'TCGGGACTCACGCCATACCTGG',
#  'TCGAGGCCAAGTCTACCGTGGG',
#  'GCTGCGCATTCATACCTCGAGG',
#  'AAGAGGTCGAATGTAGAAGTGG',
#  'TTGACTACGCCCAGAAAAATGG',
#  'TGCGCCGTGCTGAACCACCTGG',
#  'GGTCAATTCAATGTTGGGCAGG',
#  'TACCATAGGTGAACATGCGTGG',
#  'ACTTCCTGTACTGCACCGGGGG',
#  'AGTGATGAAAGGTCTAAGCAGG',
#  'AACGTACTACCCGACGGTCTGG',
#  'TTCTGTAACCACGGGACAGTGG',
#  'AACCCCAGTTAGTGACCGGGGG',
#  'CAAAACGACCGCACCCCCTTGG',
#  'CCGAAGCCAAGCAGATCGAAGG',
#  'CATTCCCAAGGGACCCGGAGGG',
#  'GACATCGATAGAGACATGGCGG',
#  'TCGGAGGGGAAAGCCCCATGGG',
#  'AAGACCTCCTCCAAAACCATGG',
#  'TGGACGAAGTAGTAGACCCAGG',
#  'CTGCATCACTGTCAAACCTGGG',
#  'AAGAGTGGAGATGTGCCCTAGG',
#  'TGCTTGGGCACAACCTAGGTGG',
#  'AGGTACTGGCGGAGGACATTGG',
#  'AGAGAATCCGTGGAGCATGAGG',
#  'AACCTGCACTTGGTCTGCGTGG',
#  'TGGATGACCTGTCCATAGATGG',
#  'CAGGCTGGAGACATCCGATGGG',
#  'CTTCCAAGCCTAGCAGGACTGG',
#  'TTCCCCGGCCTGACATGGGAGG',
#  'TCCATCAATCATATCTCACAGG',
#  'AGCAACACTAGCTAGAGATTGG',
#  'GTAGTCTGCCACCCGAGTCAGG',
#  'CGAACTGGTCGTTCAAGGTTGG',
#  'CCTGACATAGGGGGACTAGGGG',
#  'TATGGAGAAGGTGGCCCGAAGG',
#  'CGATGACCTTCTGGCCGGGGGG',
#  'CTGCAGTAGGGCGTGAGAGGGG',
#  'TTGGCTGCCTGGACGACATTGG',
#  'CTGTCTCGAAAGAGCATCAAGG',
#  'TCTTGGCGGTTTGGGCCGGGGG',
#  'GGCGTCGTTTAGGTGTAGAAGG',
#  'TCTAATGCACTAGACGTAGTGG',
#  'CGAGAACGAGTTTTACCTGTGG',
#  'TGGACGCAAGAACTTCAAGAGG',
#  'GCCGCTCGTTGGAACTCCAAGG',
#  'CATCTCGCTGAGATACGAAGGG',
#  'ATCATTCAACGGTGGCCGACGG',
#  'GTCCCCCAACTACGACAAGTGG',
#  'AGGTCAATTCCCGGGTAAGGGG',
#  'TCCCCCATCCACGACAAATGGG',
#  'TCCATCTCGCTCAGGTACGAGG',
#  'GTTCGCTCTAAGAATGGGCAGG',
#  'GATAGCCTCATTTAGTGCCTGG',
#  'AAGCTTTGCATCGTCCCTATGG',
#  'TCCATCGGTCCACGAGCCAGGG',
#  'CATCCGATCCCGAACATCCTGG',
#  'TGCTAAATCCTTGTAATCCAGG',
#  'TTACATAGATAGTATGACCTGG',
#  'GTTTATTTTACAGCCTACCAGG',
#  'TGAGTAGGAGATCATGTCGGGG',
#  'GGGCGGTCGATGTCATAGATGG',
#  'GCAGCCCTTCCTAAAAGTAAGG',
#  'ATCCTGGACTACAGGGACTTGG',
#  'TTACATAAATCACACGGCTCGG',
#  'CTCGTAGTCCGAGGACAGTAGG',
#  'ACACTCACGTGTAGGACTAGGG',
#  'CTCCGAGTGACCCGGTCAATGG',
#  'GATAACTATAAAGTCGCTCTGG',
#  'CGCTTTGTACACACCGAGCTGG',
#  'GACTCATCGATGTACGGCATGG',
#  'ATCTACAGGATATCGGGCGTGG',
#  'ATCTTCACACCGAAGACGCCGG',
#  'CCCCGTCCAAAAAGCAGACCGG',
#  'TTCAGGCTCATATCTCGGCTGG',
#  'CGGACGTGATTGAGATGAACGG',
#  'CACATTTTCTCCTCCGCGTTGG',
#  'AGCATCCCTCTCGTACCTGTGG',
#  'AAAGAGGTGTCCAAAACGGTGG',
#  'TTGATGTGAGAAACCTCAGGGG',
#  'AATGAGAACAGCATCAGGCAGG',
#  'GAAAGTTAAGCGTGAAATTTGG',
#  'GTTGGCACATTTATCATCACGG',
#  'TCCTACCAATGCTTCAAAGAGG',
#  'TCTTAAAGCTGCAAAACGAAGG',
#  'AGAAGGTTGCGGACGTGCAGGG',
#  'ACGCGTCCGACCTCGCCATAGG',
#  'CTTCTTGCGTCTCACGAACCGG',
#  'AAGGACTACACCGAGGGATGGG',
#  'ATAGGCGTGTTGTGTAGACTGG',
#  'GCACCTTCACACACGTGCCTGG',
#  'GTTGAAGCCGTCAGGACAAGGG',
#  'GACTACTTCCGAGCCCTGCTGG',
#  'GTCGGGTGAGATGCCATGCAGG',
#  'GCACGTGAGTGAAGACGTCGGG',
#  'CGTGGACAGCGGCGACATCCGG',
#  'ACGCGCATCCACTCCATGAGGG',
#  'GCTCGCTCGTCATGGCCCAGGG',
#  'GCGTACTCGTGGATGCGCACGG',
#  'AGCGCCTGCGAGTTGGACTTGG',
#  'TGCCGAGAGAAGCTCGTCGGGG',
#  'CTTGGTGCCCTTGTCATCATGG',
#  'GGCATTTCACGGGAGAAGCAGG',
#  'GAAATGGGTCTTATGACATTGG',
#  'CAATAGACAGTGTTCGTCGGGG',
#  'CATCTCTGCTGTGACTGCAGGG',
#  'TTGATATCTGATCCAAGCTTGG',
#  'AGCCCTTCGAACATACACCTGG',
#  'CGAAGTGCTACTTTGGCATTGG',
#  'TCCATTACGTCAAGCGACCTGG',
#  'CTAGATATCGCATCACAATTGG',
#  'GTTAGAGACGCTATTCCGCAGG',
#  'GATGACTACTCCTCCGACGAGG',
#  'TCTCGTGAGTCTACCCGGAAGG',
#  'GGCGACTTTAGGACTACCGTGG',
#  'CGTGGAGCCACATACCGGGTGG',
#  'AGCGTCTGGGCGACAACGGTGG',
#  'GAGCGGTGATTTTCGACATGGG',
#  'CCAACTTACTACATCAGGCTGG',
#  'GATCAAGAACGTTAGGGACAGG',
#  'TATATGGCTCGTCTGTGGCTGG',
#  'TCCACGCCAGGTACGAACCTGG',
#  'AGATCCTTACGGTCGATGCAGG',
#  'AGCCCAGCTAGGCTTCGGAGGG',
#  'CCGAAGCTATCAATCATCCAGG',
#  'CTCCATGGTACAGAGCGGTGGG',
#  'TGGTCATGTGCCGAACAGGAGG',
#  'CTTTGGCGAAAGCTCGTACAGG',
#  'AATCAGTTCTTGGGACCCGTGG',
#  'GACTCCCGAAAAATTGACCAGG',
#  'TTGCCTAAACTGGCGTCCGGGG',
#  'GAGCGATGCAGCCTCAATCCGG',
#  'CCCCCTAATTAGAAGAGCCTGG',
#  'CTTATTGTGTAACAGAACCTGG',
#  'GAGCAGGCTCTGATGTAGCTGG',
#  'AGATGTGGATAACCAACGGAGG',
#  'AGCGATGTTCAGATACTAGAGG',
#  'TATCCACCTGGGCTGCAATGGG',
#  'GGCGTAGGCCAGGTAATCGAGG',
#  'ACACTCATGATGACTCCGGTGG',
#  'AGAACCCATGAGTCGCCCTCGG',
#  'GCCGTGGTCTTTGCCAGCACGG',
#  'GCACCTTTGGTTTCAACCATGG',
#  'TACAAGGATTATTTCAACAAGG',
#  'TCCACTGTGCTCGTGATAGAGG',
#  'TAGTAGATCGTGATACTCCGGG',
#  'TTTTCGAATGTTAACGGGCAGG',
#  'CCCGGCGGCCCTATGCCGGGGG',
#  'TTCCCTTACCGGACGGGTATGG',
#  'CCTCGAAGAAACGGGACACAGG',
#  'CTCCACCAAACGGGCGTACTGG',
#  'GTCTAACCGAGCCCTCAAGCGG',
#  'GATGTGTACTGCTTCGCCGAGG',
#  'GGCGTCGTAGCGGGATGAGGGG',
#  'AATGACCGCCCCCGTGCGCAGG',
#  'ATGGCTTCACCTGACGGTCTGG',
#  'GGTAGACCGTTCTCACGCCTGG',
#  'AATGCCGACAACGAAGGCGCGG',
#  'CCTCCGCATACCGCCATCATGG',
#  'CTCGCCGGGATTTCTGGCGGGG',
#  'CTTTGAGGACGGCTCGAGCTGG',
#  'ATAATCCAGTGCCCGTCCCCGG',
#  'CTATAAGCAGTAGCAATACTGG',
#  'GATTCCGAAAAGCTGCGCCAGG',
#  'CTATAGGATAATCCGACTGTGG',
#  'ATTACTAGAATACTGAGCCAGG',
#  'GTATTGCAATGATTGATACTGG',
#  'CTGTCAGGGCTCTCGCGGTAGG',
#  'TTGACGTGGACGCGCCCAGTGG',
#  'AGGTTCGCTGACAGCCTACAGG',
#  'CCACGCTCCCGAGTGTCGGTGG',
#  'GTCGATGCTGCTCGTGGACGGG',
#  'CTGCCTAAAAAAGATCCAATGG',
#  'TGGTACATGGAGTAGAAATAGG',
#  'AGTCTTATGTGTGGACATCAGG',
#  'TTCATTACATATGGAACATTGG',
#  'AATATTGCACGAAATGAACAGG',
#  'CAGTCCAGTCAATAGGGATAGG',
#  'CATATGGGTATTACAGGTAAGG',
#  'CAAGTGAGTAGAGAAGATCAGG',
#  'TACAATCTCTTTGTCAAAATGG',
#  'TTCTAGTTGACACCAAAACTGG',
#  'GAGGAAAGGCTTCGACGGGAGG',
#  'GCGTCCCACAAAATAGAGAAGG',
#  'ATGTCTAAAGAGGATGCCATGG',
#  'CAGACACTTGTCCTGAGGTTGG',
#  'TCGCGGCCCGGGCGCCTCAGGG',
#  'CGCAGCATCTCTTCATAGGAGG',
#  'ACTACAAGCAGGCCACCATGGG',
#  'CCACTTATATCGTCCAATGGGG',
#  'GTGATCGACACAGTGCCCCTGG',
#  'TACTTCGAGCCCCTGTACCAGG',
#  'TTTTATAGCTTCTATAAGCAGG',
#  'ACAGCTTTACGTCCAACAATGG',
#  'AAGCCCATTGATGAAAACTTGG',
#  'ATGCCAGTTCTTCCCTGAATGG',
#  'GGAGTTCTGATATAACCTCAGG',
#  'TAAAAAACTAGATCCAGGTTGG',
#  'TCCATATTGTAGGGAAGCTTGG',
#  'CTGTATGCCAGGTACAAACAGG',
#  'CTGATTCAGGTGGCCAGCAGGG',
#  'CCCCATAGCCCTGAGATCGAGG',
#  'TTAAAAGGCAAAGCCAAATGGG',
#  'CAGGAATGCTAGATTTAAAAGG',
#  'TTCTTTTGCCAGCGTGTCCAGG',
#  'TTTACAAACAAGCAATAGTTGG',
#  'GAGAACTGAAAGAACTCTATGG',
#  'AGTAGCCATGGGGAAGATCTGG',
#  'CTCATCATACTCATCCATGTGG',
#  'AGTCAGCGCGACATGCAGAGGG',
#  'GTGATAGCGCCATAGTAAGGGG',
#  'GGGAGTATACATCACCCAGAGG',
#  'ATAACGCTGCACTTGCAGCAGG',
#  'CATATTAAGCGACTCAGAAGGG',
#  'ACCGCGACCTATCCATCCGTGG',
#  'TTGGTAGGCATTGTAGTCCTGG',
#  'AGCCCACTGACTTACCGCCTGG',
#  'GTCCGATGCCTGGTGACGCGGG',
#  'CCCTGATACGTCCGACGTCGGG',
#  'CGGGCCCGTTGCATCCGCTGGG',
#  'ACGCCCTCGTGCGCAGGCGCGG',
#  'TCGGCTTCCGCGGGACAGAGGG',
#  'ATTCCATGCTAACGGACCCAGG',
#  'ACTGATGCAATGGTGGACCAGG',
#  'CTTCCTATATCAGTCCAATTGG',
#  'ATCTTCAATCAACTGGCCGCGG',
#  'TGAGCACCATCTACAGTACTGG',
#  'GGCGGATGAACTGGGACCTGGG',
#  'TATGCTATAGCCACTGCCCAGG',
#  'AGCGTCATGTGGAAATACATGG',
#  'CCTACCTATGATCATGAAGAGG',
#  'CAGACAACGTAAATGTAGCGGG',
#  'CGAGTTCTACAACACGGTGCGG',
#  'ATCTGACCCAAGAAACTAAGGG',
#  'AGGGGTAGGTTCAAGGTGGTGG',
#  'GCACGTCGTAACCGCAGACAGG',
#  'GCTCATCGCAGAGCTAAAGAGG',
#  'TCGGCGATGTACCAGGTCACGG',
#  'TCTGAACTGCACCGAACATTGG',
#  'CAGAGTGTTAGAGACGGTCTGG',
#  'ATTAAACTGAATAGAACTAAGG',
#  'AAAGAGCCGATATTCCATCAGG',
#  'GATGTCGGGTCACCCCCGAAGG',
#  'CCTCCTTGGACGTGTACGATGG',
#  'TGTCCACACGTTGAGGTACAGG',
#  'TCCGGTGGCAGAAAGCGACGGG',
#  'ATTCGCCTGAAGACCCCCGGGG',
#  'TTCAACACTGCCCTCCGGGCGG',
#  'GTCAGCAATGATGACCGCCCGG',
#  'ATATGCCGGACAGTCACTCAGG',
#  'CAGAGCGTAATGGCGATGATGG',
#  'CCTGGTCGGAAACGACGCTGGG',
#  'GAAGGAGAGCGTGTAGAGCAGG',
#  'GGCATGATTGCCAACTCCGTGG',
#  'CAGTGCGTGTCATAGCCTGTGG',
#  'TGCACGTGAGCTCGCCCATGGG',
#  'TTGTTGGACGCAGACGTGACGG',
#  'GCATAAATTGCCACTACCATGG',
#  'CTGCATTAACAGCCCAAAAAGG',
#  'CTAAAGTCCCCAGCCAATCAGG',
#  'TACTGTATAAAAAACCAGCTGG',
#  'TTGATGTTCCTAGGTAGCGGGG',
#  'CCTACCGATGTGCTCCCGCTGG',
#  'CTAGGGGGTGTCAACGAGCTGG',
#  'GGATATGCCTCCCGCCCGAAGG',
#  'ACGTAGTCCCCTTCTCGGGTGG',
#  'ACCAGCTGATCAAACGTCGTGG',
#  'CTAAACATGACAGGAACTGTGG',
#  'GGGTAGCTCACAACGGTGCTGG',
#  'GCTTTCCCGGGGTCCAAATTGG',
#  'GGCACCCACGTCAACGAGTGGG',
#  'GAGTGGGACCTGAACGCGCAGG',
#  'AACTCATCACAATTCCGAATGG',
#  'GGCTCACGTAAAGTCCTGCAGG',
#  'ACATGCGGATTATTCCCCCTGG',
#  'ATCGTAGCTCGGTCAGCAATGG',
#  'GAAGTTAGTATCACGTACCTGG',
#  'ACATTGTTCGCAAACGGTAAGG',
#  'GCGAGGCAAGTCGTACCTGCGG',
#  'GACGGGCTCTCTCTCCGGTTGG',
#  'GTGCAATCGTGGAATACCACGG',
#  'CGTGTTCCCTTACAACCACAGG',
#  'GCGCCCTTCTCGTCGCGCAGGG',
#  'GCTACCGCGCCGACACCCTTGG',
#  'GTAGCGCTCGTGCCGCACCCGG',
#  'GAGTATCGGGCTAGTCTGCTGG',
#  'TATCCCTCGCCGTCTGCCATGG',
#  'ACGGCTTGCCTGTCCGGTAAGG',
#  'TTGAAGGCCCGGTTCACCTTGG',
#  'TTCAATGGCCTTCAGCGTAGGG',
#  'ACCAGACGGTCGCCGACCTGGG',
#  'GTTGAAGTTGGAGTTCGCGTGG',
#  'TCCGGGGACCATCTACAGTTGG',
#  'ATATCTACGGACTTCAGAAAGG',
#  'CGTGATGGTTTGCATGGGGTGG',
#  'ACCAGTTCAATGCTCTGAACGG',
#  'TGGAGAGTGCCTATTGCATTGG',
#  'CGTGGCTGTCAAACCGCCGTGG',
#  'GTAGATAACATATCAACAATGG',
#  'CTCTGCTATGCACGGAAAGGGG',
#  'TTCATATCGACACTGACTCCGG',
#  'GTACAGCCGGGACGCTCGAAGG',
#  'AAGAGTTCGGCGCAGTTCCTGG',
#  'CGCGCACGGCGATTCGCACCGG',
#  'GTAGCGCTCGTGCCGCGTCTGG',
#  'CGGCGCCAGTCGGTGCGAGCGG',
#  'TTCTTTTCTTCCAGGTAAAAGG',
#  'GATCCATTGATGGAAACTGTGG',
#  'CTACTGTGCTTATAGTTGATGG',
#  'CGTGGACATTGTGGATATAAGG',
#  'TTCTCGCAGTATTCCCGGCAGG',
#  'AAGGGCACCTTACCACAACAGG',
#  'GGTGCGCTCGACACGAGCCAGG',
#  'CGGCCACACAGCGCTCCTGTGG',
#  'CATTGCAACAGCCAGAACGGGG',
#  'CCTTAAATACTGGTCAATGAGG',
#  'CTGTGAAGGCCGTGCAACATGG',
#  'AAGTGGAGCGGACACGAACAGG',
#  'CCGAACAAAGTAGCAGTGCAGG',
#  'GGTGGTCAGATCGTGGGCCAGG',
#  'AGTAACGACGTGGAGCTGAAGG',
#  'AAGAGGAGCTCTTTAGACAAGG',
#  'TGAGTGGATTTACAAATGCCGG',
#  'GGGCTGTAACTATCGATAAAGG',
#  'TGTAACAAATAAGAACTGCAGG',
#  'TGTGGTTTCCAAGCCTCGAAGG',
#  'CGCAGCCAGCGTTATGAGGTGG',
#  'GCGCTGTATCGGATGGCAATGG',
#  'GAATTACCGTTGGTGACATCGG',
#  'TCACGAATAGGTACGATAAAGG',
#  'CGGTTGATAGCTCGGCGCCTGG',
#  'TTATAAGGCTGCCATGCGGAGG',
#  'CGGATGACCGAGTAGCGCATGG',
#  'GCTGTACCGAGTTTGACGTAGG',
#  'GAACCATGTGCGGGTCCCCAGG',
#  'AAACTCGGGCAGAACGGTCTGG',
#  'GGCCTTGGTATTACTGCCGTGG',
#  'GAACTTCCTTCGATGCAAGCGG',
#  'CGCACGCCTCACCTTAAAGCGG',
#  'GTCCCTCCCGTAGGACGTCAGG',
#  'GATGTTTGCAATGACCGAGAGG',
#  'GACACGCCGTGTGAAAATGCGG',
#  'GCTGCATAATTCCCGTACATGG',
#  'GACAAGGTTCGGATACCCAGGG',
#  'GCGAATGGTACTGTCCATCTGG',
#  'TTCTCTGAGATGTTTTGATCGG',
#  'CAACTTCCGGGTATGAGATAGG',
#  'GAACCCCCCTGACTACCGAGGG',
#  'CTTCATGCAGCTCTGCCCTCGG',
#  'TCCCATGAGCCACGTTGCCCGG',
#  'TCCAAGGACGGTACCTGCCGGG',
#  'TTTGATTATATACTATGTATGG',
#  'TATGGATGAAAGCAATCTGAGG',
#  'CTGTTTCTGACTGGAACGTGGG',
#  'TGAGCTGCCTAAGAAATCATGG',
#  'GTCTACCTGTCTTGCTTTATGG',
#  'ACCTCTTGCCGGTGATAAGAGG',
#  'CCGTGATAGCGCTGCCGCAGGG',
#  'GGTTAACTGACCAAACCCCTGG',
#  'CCAGTGAAGACATATCCCAAGG',
#  'CACTGGTGAACGGTCTCCATGG',
#  'GATCTTAGAGTATGCAATCTGG',
#  'TTTCCGGCTAGCACGTACCAGG',
#  'CTCCCTTCGCAAAGTGCCCTGG',
#  'TCAGAGAATACGTCCTCAAAGG',
#  'TTCCCGGGCCGTGTGGAATGGG',
#  'ACACAGTCACCAATCTAGCTGG',
#  'GGGTGGGACCTCTAATAGCTGG',
#  'TTTGTACTAACAGGTAGAGTGG',
#  'CGTGTTTCGACACGGGGCTCGG',
#  'TCGACCGGACACTGGCCATCGG',
#  'ACTTTCAGGTGTTTCGGCATGG',
#  'CCAAATCCTTGTGGCCATGAGG',
#  'TGGAGCAGCATTATGAACTTGG',
#  'CTCAAGTTCTTGAAAACGAGGG',
#  'CTTTCAGGATTACATGGCCAGG',
#  'CGGTACTCCGGACTCAGGAAGG',
#  'ACGGACTTTGACCGCACGCTGG',
#  'CTCGGGAAACAGCCCGGCAAGG',
#  'ATCGGGGACAGCTGCGCATGGG',
#  'AACTTCACGGGACTGTCGCTGG',
#  'GTCCGCATCGTCGGCGGGAAGG',
#  'AGCTTGCTGAATTCACGATGGG',
#  'GCGCCCACACGAAATGGGAGGG',
#  'CGTGTGGATCTCATCGACCTGG',
#  'GGTCGAGTTACACAAGTCCAGG',
#  'ACTCTACTTCTCGTACCCGGGG',
#  'GCAACGGTAGTGAGTGAACTGG',
#  'ACCATCGGGCACTAAGCCGTGG',
#  'GTGGGATTCCGGCAGCCGTGGG',
#  'TGGGTTGCACGGAGACGGCAGG',
#  'CATCCTTAATGTCCAGTCAAGG',
#  'TATTGGAAATAAACAGCGACGG',
#  'CAGAAGATTTGTGTAATGAAGG',
#  'AAACTTCAGGGTTAGCCTCAGG',
#  'TCCCTGATTGTTCCACCACAGG',
#  'GAACAGCCTTCTGGTGAGCAGG',
#  'CTTTGAGTGAGCTTGAGTCAGG',
#  'CAAAGGCTGTTCTCCGGAGAGG',
#  'CTTCAGGTGAACACCTCTCCGG',
#  'CTTCAGTTCAGCAACTTCCAGG',
#  'GTGCATCGGATGTTCTACGAGG',
#  'GACGACTCGGGCCGATGGGCGG',
#  'AGATCTACGACCTGTGGACAGG',
#  'GCCCATACCGTGTACACATTGG',
#  'TCATAAGCGATGTACTGGCAGG',
#  'CCGACAAGCCTCATAGTACTGG',
#  'CCAATGACCTTACCCGGCTAGG',
#  'TGACAAACCTCGGCAGAGTTGG',
#  'TGGGTAGGGGTTTACCGAAAGG',
#  'CCTTATGTTACAGATCACGTGG',
#  'AAGCGGACACCCTGCAACCTGG',
#  'GCATGGTCTCCACGCCCATCGG',
#  'GCACCCCTGAACGTAGCTGAGG',
#  'GGGACCTAACTCCTATGCATGG',
#  'CATCCAGTTCACCTCGGTAGGG',
#  'CGGCCGTGCTGGTCAACCAGGG',
#  'ATAAAGCTCCCTGTACGTGTGG',
#  'AACGATGCCTCCTACGTCGTGG',
#  'ACTCATCCATGACGCCCACTGG',
#  'CTTAAGTTCTGAAACGCCGCGG',
#  'GATGCCTACGGCAGTGAACTGG',
#  'ACCAGACCAACCCTATGAATGG',
#  'TTTCCGAGAGCCTAAACAAGGG',
#  'TATACGAAGGTTTCCAGAGGGG',
#  'GGTCTCGTGGCGTACCAGAAGG',
#  'TGGCTTCAGTATTATACCCTGG',
#  'TTTCTCACGGATGCCGCATTGG',
#  'TCAACACTGGTAATCAGATAGG',
#  'TAGGATTTCCCTGGTCCCAAGG',
#  'TCCAGGTATTCTTTCACACTGG',
#  'ATTTGATAGCTGGAATGACAGG',
#  'GTTCTACTGGCCGACCTAAGGG',
#  'GTTTCACAAGCGGCACGACAGG',
#  'GATGTAGCGGATAGCCCCAGGG',
#  'TAGAGCGGGACCACCACCATGG',
#  'CCGGGCATCATCATAGTAGTGG',
#  'GGCGATCTGTGATTGGGTCTGG',
#  'GACTCACTTAACCAGCGATCGG',
#  'AAGACGTTGGCTACACGGCGGG',
#  'AAGTTATGTACTGGACTACTGG',
#  'AATGACTATGAAGTACCGGAGG',
#  'AATCCATCCTGAGTCCGACAGG',
#  'CACACGATCCCCACGCTGCAGG',
#  'GTGCTCACTTATGGAACCTTGG',
#  'AGCAACATCCGGTAAACAATGG',
#  'CAGAACTGCGTCACTGTAGGGG',
#  'ACCGTTTCTGTCTGGCCATAGG',
#  'AAACTTGGCCGGCACTTCCTGG',
#  'ATCTACAGAACTGCCTCGCTGG',
#  'GAACATTCCTACTCGAGCCTGG',
#  'CTGCCATCTACTTCACTAGTGG',
#  'AACTATGAATCCATGAAACAGG',
#  'TGAAACAGGACTTCAAACTGGG',
#  'CTTATCAGTCCATTGGTCCAGG',
#  'CGATGGAGTTTTGAGGAACTGG',
#  'AGCCATAAATCGCTGTAACAGG',
#  'ATGTAGCTTGCATACGAACAGG',
#  'TACAATGGACTCCACCGCTGGG',
#  ...]

# %%
temp=df2[0].unique()
temp=temp[0:-1]
len(temp)
# Out:
# 747169

# %%
temp=df2[0].unique()
print(len(temp))
temp = fix_length(temp,length=20)
# print(len(temp))
temp = fix_length(temp,length=21)
# print(len(temp))
temp = fix_length(temp,length=22)
print(len(temp))
temp = fix_length(temp,length=24)
print(len(temp))
# Out:
# 747170
# 965615
# 965459

# %%
myfix=[]
counter=0
for i in range(len(temp)):
    if len(temp[i])!=23:
#         df2[0][i]+="GG"
        myfix.append(temp[i])
        counter+=1

counter
# Out:
# 0

# %%
df2=pd.DataFrame(temp)
df2.columns= ["sgRNA"]
df2
# Out:
#                           sgRNA
# 0       AAAAAAAAAAAGGGGGGTTCTGG
# 1       AAAAAAAAAAAGTCGTACTTGGG
# 2       AAAAAAAAAAGAGCACGATGAGG
# 3       AAAAAAAAAATTCCACCCCCTGG
# 4       AAAAAAAAAATTGCCGGGCGAGG
# ...                         ...
# 965454  TTTTTTTTTGAGACGGAGTTAAG
# 965455  TTTTTTTTTGAGACGGAGTTCAG
# 965456  TTTTTTTTTGAGACGGAGTTCGG
# 965457  TTTTTTTTTGAGACGGAGTTTAG
# 965458  TTTTTTTTTGAGACGGAGTTTGG
#
# [965459 rows x 1 columns]

# %%
df1 = pd.read_csv("/mnt/d/M3/Projects/BCB/Crispr/Dataset/unlabeled_sgrna0.csv")
df1.columns= ["sgRNA"]
df1
# Out:
#                           sgRNA
# 0       CGCCGCCGCTTTCGGTGATGAGG
# 1       GGCAGCGTCGTGCACGGGTCGGG
# 2       TGGGCGGATCACTTGACGTCAGG
# 3       TTACCATAGTGTACGGGTGCAGG
# 4       TCTACTGAAGTGGTAGCAACAGG
# ...                         ...
# 337119  GGCAGAAATGTGCTCTTGCAGGG
# 337120  GGGAAGATTTTGGACTATTTGGG
# 337121  GGCAACTTTTTATGCAAGTTGGG
# 337122  GGTAGCTGGGACTTGCCCTTGGG
# 337123  GGACTTCCAGGACTGCCTTGGGG
#
# [337124 rows x 1 columns]

# %%
df3 = pd.concat([df1,df2], ignore_index=True)
df3
# Out:
#                            sgRNA
# 0        CGCCGCCGCTTTCGGTGATGAGG
# 1        GGCAGCGTCGTGCACGGGTCGGG
# 2        TGGGCGGATCACTTGACGTCAGG
# 3        TTACCATAGTGTACGGGTGCAGG
# 4        TCTACTGAAGTGGTAGCAACAGG
# ...                          ...
# 1302578  TTTTTTTTTGAGACGGAGTTAAG
# 1302579  TTTTTTTTTGAGACGGAGTTCAG
# 1302580  TTTTTTTTTGAGACGGAGTTCGG
# 1302581  TTTTTTTTTGAGACGGAGTTTAG
# 1302582  TTTTTTTTTGAGACGGAGTTTGG
#
# [1302583 rows x 1 columns]

# %%
df4=pd.DataFrame(df3['sgRNA'].unique())
df4
# Out:
#                                0
# 0        CGCCGCCGCTTTCGGTGATGAGG
# 1        GGCAGCGTCGTGCACGGGTCGGG
# 2        TGGGCGGATCACTTGACGTCAGG
# 3        TTACCATAGTGTACGGGTGCAGG
# 4        TCTACTGAAGTGGTAGCAACAGG
# ...                          ...
# 1066619  TTTTTTTTTGAGACGGAGTTAAG
# 1066620  TTTTTTTTTGAGACGGAGTTCAG
# 1066621  TTTTTTTTTGAGACGGAGTTCGG
# 1066622  TTTTTTTTTGAGACGGAGTTTAG
# 1066623  TTTTTTTTTGAGACGGAGTTTGG
#
# [1066624 rows x 1 columns]

# %%
df4.to_csv("/mnt/d/M3/Projects/BCB/Crispr/Dataset/unlabeled_sgrna.csv", index = False, header = True)

# %%
with open("/mnt/d/M3/Projects/BCB/Crispr/Dataset/unlabeled_sgrna.txt","w") as f:
    for i in df4[0]:
        f.write(space(i, mer=3)+"\n")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d67f66e6b3a9> in <module>
#       1 with open("/mnt/d/M3/Projects/BCB/Crispr/Dataset/unlabeled_sgrna.txt","w") as f:
# ----> 2     for i in df4[0]:
#       3         f.write(space(i, mer=3)+"\n")
#
# NameError: name 'df4' is not defined
